# %%
# !pip install nltk
# !pip install spacy
# !python -m spacy download es_core_news_sm
# !pip install -U imbalanced-learn
# !pip install pyspellchecker

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Oculta warnings
import warnings
warnings.simplefilter('ignore')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # CARGAR DATOS
# **DATOS DE ENTRENAMIENTO**
#
# la columna de trastornos indica si el TWEET es de una persona con ansiedad o es de control.
#
#
# **control**:     0
#
# **ansiedad**:   1

# %% [markdown]
# #DATOS DE PRUEBA

# %%
ruta_archivo_entrenamiento = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs ansiedad)/train.csv'
data_train = pd.read_csv(ruta_archivo_entrenamiento, sep=',')
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64989 entries, 0 to 64988
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   USER_ID     32528 non-null  object
#  1   TWEET_ID    32528 non-null  float64
#  2   TWEET_TEXT  64987 non-null  object
#  3   trastorno   64985 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 2.0+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0     NaN           NaN  3522.0, intenta combatir siéntete indeseable c...
# 1   302.0  2.147484e+09  RT @giraltpablo: Lamentablemente, Ecuador perd...
# 2     NaN           NaN                       Minitrigos helados ansiosos.
# 3     NaN           NaN  Está bien. Yo he estado ahí antes. Dudaba de m...
# 4     NaN           NaN  ¡Siento escuchar eso! Considere la posibilidad...
# 5   480.0  2.147484e+09  No entiendo eso de apoyar en una final,al equi...
# 6   266.0  2.147484e+09  "Come On" - @akapellah feat @BigSotoLuc &amp; ...
# 7     NaN           NaN  ,Hola, chico, aparentemente tiene una enfermed...
# 8   390.0  2.147484e+09  RT @excelentum: El que domina su cólera, domin...
# 9   288.0  2.147484e+09       RT @Guillodibujante: https://t.co/YO0oAArJJq
#
#    trastorno
# 0        1.0
# 1        0.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        0.0
# 6        0.0
# 7        1.0
# 8        0.0
# 9        0.0

# %%
# Verificar si hay filas nulas o vacías en la columna 'trastorno'
null_values = data_train['trastorno'].isnull().sum()

# Imprimir el número de filas nulas o vacías
print("Número de filas nulas o vacías en la columna 'trastorno':", null_values)
# Out:
# Número de filas nulas o vacías en la columna 'trastorno': 4

# %%
# Eliminar filas con valores nulos en la columna 'trastorno'
data_train = data_train.dropna(subset=['trastorno'])

# Verificar si hay filas nulas o vacías en la columna 'trastorno' después de eliminarlas
null_values = data_train['trastorno'].isnull().sum()

# Imprimir el número de filas nulas o vacías
print("Número de filas nulas o vacías en la columna 'trastorno' después de eliminarlas:", null_values)
# Out:
# Número de filas nulas o vacías en la columna 'trastorno' después de eliminarlas: 0

# %%
data_train['trastorno'] = data_train['trastorno'].astype('int64')
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64985 entries, 0 to 64988
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   USER_ID     32524 non-null  object
#  1   TWEET_ID    32524 non-null  float64
#  2   TWEET_TEXT  64985 non-null  object
#  3   trastorno   64985 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.5+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0     NaN           NaN  3522.0, intenta combatir siéntete indeseable c...
# 1   302.0  2.147484e+09  RT @giraltpablo: Lamentablemente, Ecuador perd...
# 2     NaN           NaN                       Minitrigos helados ansiosos.
# 3     NaN           NaN  Está bien. Yo he estado ahí antes. Dudaba de m...
# 4     NaN           NaN  ¡Siento escuchar eso! Considere la posibilidad...
# 5   480.0  2.147484e+09  No entiendo eso de apoyar en una final,al equi...
# 6   266.0  2.147484e+09  "Come On" - @akapellah feat @BigSotoLuc &amp; ...
# 7     NaN           NaN  ,Hola, chico, aparentemente tiene una enfermed...
# 8   390.0  2.147484e+09  RT @excelentum: El que domina su cólera, domin...
# 9   288.0  2.147484e+09       RT @Guillodibujante: https://t.co/YO0oAArJJq
#
#    trastorno
# 0          1
# 1          0
# 2          1
# 3          1
# 4          1
# 5          0
# 6          0
# 7          1
# 8          0
# 9          0

# %% [markdown]
# # DATOS DE PRUEBA (TEST)

# %%
ruta_archivo_prueba = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs ansiedad)/test.csv'
data_test = pd.read_csv(ruta_archivo_prueba, lineterminator='\n')
data_test.info()
data_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27853 entries, 0 to 27852
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   USER_ID     13894 non-null  float64
#  1   TWEET_ID    13894 non-null  float64
#  2   TWEET_TEXT  27853 non-null  object
#  3   trastorno   27853 non-null  int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 870.5+ KB
#    USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0    264.0  2.147484e+09                                @sua_agu10 Wiiiinaa
# 1      NaN           NaN  ¡El alcohol es lo malo! ¡No marihuana! Defende...
# 2      NaN           NaN   Dios, ni siquiera había considerado que mi an...
# 3      NaN           NaN  1663.0,solo dios alma espera silencio ven salv...
# 4    316.0  2.147484e+09  @andresacosta20 @latengorepetida @PANINIcol ca...
#
#    trastorno
# 0          0
# 1          1
# 2          1
# 3          1
# 4          0

# %% [markdown]
# #Preprocesamiento de los datos

# %%
import nltk
nltk.download('stopwords')  #Solamente se ha de descargar la primera vez.
stopwords_es = nltk.corpus.stopwords.words('spanish')   # Extrae las stopwords en español
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# *Eliminar etiquetas HTML*

# %%
import re

def removeHTML(text):
    if isinstance(text, str):  # Verificar si es de tipo string
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, '', text)
        return cleantext
    else:
        return text  # Devolver el valor original si no es de tipo string

# %% [markdown]
# *Limpieza del texto*

# %%
import re
import string

def clean(text):
    if isinstance(text, str):  # Verificar si es de tipo string
        # Eliminar hashtags
        text = re.sub(r'#\w+', '', text)

        # Eliminar URLs o enlaces
        text = re.sub(r'(https?://)?[a-zA-Z0-9]+\.[a-zA-Z0-9]+\S*', '', text)

        # Eliminar nombres de usuarios de Twitter
        text = re.sub(r'@\w+', '', text)

        # Eliminar Nombres propios
        text = re.sub(r'\b[A-Z][a-z]+\b', '', text)

        # Eliminar todos los caracteres especiales
        text = re.sub(r'[^\w\s]+', '', text)

        # Eliminar prefijos y números
        text = re.sub(r'\b\w{1,2}\b|\d+', '', text)

        # Eliminar palabras específicas
        specific_words = ['retweet', 'retweets', 'hashtag', 'trending', 'mención', 'enlace', 'emoji', 'timeline', 'interacciones',
                          'tuit', 'seguidores', 'notificaciones', 'seguir', 'favorito', 'perfil', 'tendencia', 'influencer',
                          'compartir', 'actualización', 'explorar', 'seguir', 'comunidad', 'contenido', 'popular',
                          'recomendar', 'experiencia', 'conectar', 'comentar', 'compartir', 'comunidad', 'actualización',
                          'drk', 'followers', 'stats', 'for', 'new', 'little', 'unfollower', 'unfollowers', 'today', 'shit','twitter','nombre',
                          'eric','story','great', 'short','squeeze','piggly','wiggly','hmv','even','follas','you','i','he','she',
                          'it','we','they','the','and','that','these','those','tweet','followed','follower']
        text = ' '.join([word for word in text.split() if word not in specific_words])

        # Eliminar emojis
        emojis = re.findall(r'[^\w\s,]', text)
        cleaned_emojis = [emoji for emoji in emojis if emoji not in ['@', '#', '/', '?','¿','.','…','"',':','“','!','¡','°','-',"‘",'’',
                                                                     '=',';','(',')',"'","'",'&','€','%','$','*','+','|', '”','🇦','🇷',',',
                                                                     ', ','—','«',' »','»','« ','[, ]','[,]',',',', ','',' ',' ♀',' 🏽']]
        for emoji in cleaned_emojis:
            text = text.replace(emoji, '')

        # Convertir el texto a minúsculas
        text = text.lower()

        # Eliminar signos de puntuación
        text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
        # Tokenizar el texto en palabras
        words = text.split()

        # Eliminar palabras vacías
        words = [word for word in words if word not in stopwords_es]

        # Reconstruir el texto limpio
        text = ' '.join(words)

        # Devuelve el texto limpio
        return text
    else:
        return text  # Devolver el valor original si no es de tipo string

# %% [markdown]
# *lematizar y extraer términos*

# %%
import pandas as pd
import spacy
from spacy.lang.es import Spanish
from nltk.corpus import stopwords


# Cargar modelo de spaCy
nlp = spacy.load("es_core_news_sm")

# Cargar stopwords en español
stopwords_es = set(stopwords.words('spanish'))
def extractTerms(text):
    if isinstance(text, str):
        # Tokenización y lematización con spaCy
        doc = nlp(text)
        lemmatized_terms = [token.lemma_ for token in doc if token.text.lower() not in stopwords_es]

        return lemmatized_terms
    else:
        return []  # Devolver una lista vacía si el texto no es una cadena de texto

# Ejemplo de uso
texto_ejemplo = "Los gatos están saltando sobre las vallas"
terminos_extraidos = extractTerms(texto_ejemplo)
print(terminos_extraidos)
# Out:
# ['gato', 'saltar', 'valla']

# %% [markdown]
# # Preprocesamieto del conjunto de datos de entrenamiento

# %%
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(removeHTML)
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(clean)
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(extractTerms)
data_train.head(10)
# Out:
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0     NaN           NaN  [intentar, combatir, siéntete, indeseable, per...
# 1   302.0  2.147484e+09  [perder, carta, ganador, localía, allí, escapa...
# 2     NaN           NaN                                  [helado, ansioso]
# 3     NaN           NaN  [bien, ahí, amigo, amor, saber, decir, intenta...
# 4     NaN           NaN  [escuchar, posibilidad, utilizar, aceite, esen...
# 5   480.0  2.147484e+09  [entender, apoyar, finalal, equipo, elimino, c...
# 6   266.0  2.147484e+09                                    [feat, amp, mp]
# 7     NaN           NaN  [chico, aparentemente, enfermedad, terminal, d...
# 8   390.0  2.147484e+09          [dominar, cólero, dominar, peor, enemigo]
# 9   288.0  2.147484e+09                                                 []
#
#    trastorno
# 0          1
# 1          0
# 2          1
# 3          1
# 4          1
# 5          0
# 6          0
# 7          1
# 8          0
# 9          0

# %%
# Verificar si hay elementos vacíos en la columna 'TWEET_TEXT'
empty_count = (data_train['TWEET_TEXT'].apply(len) == 0).sum()

# Imprimir el número de elementos vacíos en la columna 'TWEET_TEXT'
print("Número de elementos vacíos en la columna 'TWEET_TEXT':", empty_count)
# Out:
# Número de elementos vacíos en la columna 'TWEET_TEXT': 1798

# %%
# Filtrar filas donde 'TWEET_TEXT' no sea una lista vacía
data_train = data_train[data_train['TWEET_TEXT'].apply(len) > 0]

# Reiniciar el índice del DataFrame después de eliminar filas
data_train.reset_index(drop=True, inplace=True)

# %%
# Verificar si hay elementos vacíos en la columna 'TWEET_TEXT'
empty_count = (data_train['TWEET_TEXT'].apply(len) == 0).sum()

# Imprimir el número de elementos vacíos en la columna 'TWEET_TEXT'
print("Número de elementos vacíos en la columna 'TWEET_TEXT':", empty_count)
# Out:
# Número de elementos vacíos en la columna 'TWEET_TEXT': 0

# %%
# from spellchecker import SpellChecker

# def corrector_ortografico(tokens):
#     spell = SpellChecker(language='es')
#     tokens_corregidos = [spell.correction(token) if spell.correction(token) is not None else token for token in tokens]
#     return tokens_corregidos

# def corregir_palabras_largas(tokens):
#     tokens_corregidos = []
#     for token in tokens:
#         # Corregir repeticiones de letras
#         token_corregido = re.sub(r'(.)\1+', r'\1\1', token)

#         # Corregir alargamiento de palabras
#         token_corregido = re.sub(r'(\w)\1{2,}', r'\1\1', token_corregido)

#         # Eliminar vocales repetidas más de 2 veces seguidas
#         token_corregido = re.sub(r'([aeiouáéíóú]{2,})\1+', r'\1', token_corregido, flags=re.IGNORECASE)

#         tokens_corregidos.append(token_corregido)
#     return tokens_corregidos

# %%
# data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(corregir_palabras_largas)
# data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(corrector_ortografico)
# data_train.info()
# data_train.head(10)

# %% [markdown]
# #Representación de los datos
#
# La caracterización de texto mediente Embedding transforma cada palabra del contexto en un vector de embedding.

# %%
import gensim
from gensim.models import Word2Vec
# Entrena un modelo Word2Vec usando CBOW
modelW = Word2Vec(data_train['TWEET_TEXT'], vector_size=300, window=5, min_count=1, sg=0)# - vector_size: el tamaño de los vectores de palabra
# - window: el tamaño de la ventana de contexto
# - min_count: el número mínimo de veces que una palabra debe aparecer para ser considerada
# - sg: 0 para CBOW, 1 para Skip-gram

# Obtener la representación vectorial de un documento promediando las palabras
def document_vector(tokens, modelW):
    # Filtrar palabras que no están en el modelo
    tokens = [token for token in tokens if token in modelW.wv.key_to_index]
    if len(tokens) == 0:
        return np.zeros(modelW.vector_size)
    return np.mean([modelW.wv[token] for token in tokens], axis=0)

# Crear una matriz de características X utilizando las representaciones vectoriales de Word2Vec
X = [document_vector(tokens, modelW) for tokens in data_train['TWEET_TEXT']]

# Obtener las etiquetas y
y = data_train['trastorno'].values

# Ahora puedes usar X e y para entrenar tu modelo de clasificación como se mencionó anteriormente

# %%
# Imprimimos el la longitud de las palabras totales
print(modelW)
print(len(modelW.wv))
# Observamos el vocabulario creado
words = modelW.wv.index_to_key
print(words)
# Out:
# Word2Vec<vocab=43816, vector_size=300, alpha=0.025>
# 43816
# ['ansiedad', 'poder', 'hacer', 'depresión', 'necesitar', 'día', 'vez', 'ser', 'decir', 'querer', 'persona', 'solo', 'año', 'ansioso', 'bien', 'tiempo', 'sentir', 'ver', 'cosa', 'así', 'tanto', 'mejor', 'gente', 'vida', 'momento', 'mismo', 'medicamento', 'ayuda', 'saber', 'tomar', 'pasar', 'ahora', 'ir', 'dejar', 'ayudar', 'realmente', 'pensar', 'alguien', 'cómo', 'miedo', 'hablar', 'casa', 'todo', 'hoy', 'amigo', 'dar', 'nuevo', 'tener', 'siempre', 'trabajo', 'deber', 'semana', 'amor', 'trastorno', 'mucho', 'volver', 'poner', 'bipolar', 'creer', 'nunca', 'difícil', 'problema', 'buen', 'sólo', 'salir', 'esperar', 'después', 'cada', 'estrés', 'primero', 'favor', 'trabajar', 'mañana', 'médico', 'menos', 'hora', 'aquí', 'mental', 'todavía', 'noche', 'vivir', 'dormir', 'lugar', 'mundo', 'dos', 'tratar', 'gran', 'llegar', 'mal', 'encontrar', 'foto', 'seguro', 'niño', 'hijo', 'seguir', 'simplemente', 'cualquiera', 'social', 'alguno', 'ataque', 'parte', 'salud', 'enfermedad', 'parecer', 'demasiado', 'último', 'mes', 'alto', 'amar', 'luchar', 'pánico', 'hecho', 'entender', 'familia', 'punto', 'manera', 'funcionar', 'peor', 'bueno', 'único', 'venir', 'feliz', 'nadie', 'ansiós', 'pasado', 'mostrar', 'intentar', 'diferente', 'malo', 'contar', 'siento', 'luego', 'vía', 'escuchar', 'pequeño', 'gustar', 'posible', 'perder', 'ninguno', 'fuerte', 'empezar', 'mayor', 'preocup', 'quedar', 'llevar', 'pensamiento', 'dolor', 'incluso', 'tipo', 'mientras', 'necesidad', 'recuperar', 'corazón', 'sueño', 'debido', 'conocer', 'situación', 'dinero', 'real', 'medio', 'mantener', 'importante', 'buscar', 'obtener', 'pedir', 'gracias', 'usted', 'jugar', 'antiguo', 'sufrir', 'loco', 'hombre', 'tal', 'cambiar', 'ganar', 'casi', 'recordar', 'hacer él', 'terminar', 'nivel', 'junto', 'morir', 'existir', 'mas', 'aunque', 'laptop', 'razón', 'apoyo', 'mensaje', 'horrible', 'suerte', 'sentimiento', 'verdad', 'llorar', 'mierdo', 'llamar', 'aumentar', 'aún', 'realidad', 'importar', 'tú', 'cabeza', 'comenzar', 'extraño', 'grande', 'ahí', 'vido', 'mamá', 'país', 'necesario', 'idea', 'juego', 'lado', 'cambio', 'paz', 'efecto', 'bajo', 'bastante', 'suceder', 'preguntar', 'forma', 'mente', 'virus', 'final', 'covid', 'madre', 'normal', 'gana', 'propio', 'mirar', 'leer', 'desear', 'cuenta', 'padre', 'mano', 'superar', 'próximo', 'caer', 'cuerpo', 'siquiera', 'haber', 'quién', 'cierto', 'además', 'noticia', 'vivo', 'mujer', 'acabar', 'minuto', 'igual', 'historia', 'usar', 'provocar', 'rápido', 'etc', 'fácil', 'tarde', 'recibir', 'comer', 'humano', 'largo', 'palabra', 'jajaja', 'canción', 'entonces', 'triste', 'controlar', 'lidiar', 'ver él', 'secundario', 'paso', 'comprar', 'síntoma', 'coronavirus', 'diario', 'inquieto', 'aprender', 'ánimo', 'fin', 'nervioso', 'equipo', 'segundo', 'chico', 'serio', 'atención', 'visto', 'positivo', 'control', 'suficiente', 'grupo', 'entrar', 'perro', 'preocupado', 'clase', 'acuerdo', 'caso', 'sino', 'causar', 'batalla', 'especialmente', 'aquel', 'él', 'significar', 'mayoría', 'partido', 'postraumático', 'video', 'lucha', 'demá', 'relación', 'consejo', 'mierda', 'respirar', 'completo', 'embargo', 'tomo', 'respuesta', 'lindo', 'futuro', 'encantar', 'hacia', 'mejorar', 'hermoso', 'conseguir', 'dentro', 'gusta', 'duro', 'mp', 'escuela', 'vo', 'formar', 'hermano', 'pronto', 'literalmente', 'prueba', 'cerebro', 'listo', 'arte', 'ayer', 'lleno', 'dosis', 'escribir', 'crisis', 'cansado', 'deprimido', 'episodio', 'mil', 'pagar', 'evitar', 'bebé', 'libre', 'camino', 'hospital', 'abrazo', 'pandemia', 'odio', 'libro', 'música', 'cuarentenar', 'programa', 'faltar', 'personal', 'https', 'pena', 'cerrar', 'adelante', 'despertar', 'peso', 'grave', 'comida', 'teléfono', 'mercado', 'ejercicio', 'tres', 'aliviar', 'necesito', 'valer', 'probablemente', 'joven', 'reducir', 'increíble', 'información', 'gobierno', 'jajajar', 'aparecer', 'público', 'familiar', 'enviar', 'preocupación', 'señor', 'muerte', 'allí', 'sistema', 'cerca', 'llamado', 'través', 'permitir', 'af ...

# %%
# Obtener la representación vectorial de una palabra específica
vector = modelW.wv['depresión']
vector
# Out:
# array([-0.38392287,  0.6539637 , -0.65612966,  0.09215558, -0.17326374,
#        -1.2336535 ,  0.07165793,  1.7214214 , -0.10886468,  0.07662173,
#         0.2522202 , -1.0649014 , -0.36888495, -0.5386186 , -0.28729364,
#        -0.2913603 , -0.2166889 ,  0.02017722,  0.6073137 , -1.1761177 ,
#         0.21843393,  0.08251778,  0.06967978, -0.32448334,  0.42487085,
#        -0.20289287, -0.5426514 , -0.37300515, -0.58623177, -1.2062501 ,
#         0.30282888, -0.32316586,  0.7156274 ,  0.47685772, -0.34225154,
#         1.1859877 ,  0.56941605,  0.2588781 ,  0.06487866, -0.36226326,
#        -0.10148623,  0.45121548, -0.1050512 , -0.49156484,  0.76963246,
#         0.87102705,  0.48421147,  0.6817244 , -0.25310946,  0.49701095,
#         0.36780196,  0.02400664, -0.5806611 ,  0.20295927,  0.4952074 ,
#         0.7949599 , -0.20293584,  0.1037979 ,  0.3568566 , -0.21650445,
#        -0.380486  ,  0.12632976, -0.20247975, -1.0409458 , -0.8594974 ,
#         0.26498568, -0.03877509,  0.02871398, -0.08264016, -0.3986298 ,
#         0.21581039,  0.62218684,  1.1460439 , -0.50593907,  0.15692642,
#        -0.29672316, -0.3307236 , -0.5234238 , -0.20904604,  0.94745904,
#         0.0541162 , -0.16477008,  0.6186832 ,  1.2469114 ,  0.595216  ,
#        -0.43312067, -1.0561376 , -0.24359316,  0.78513986,  0.8064503 ,
#        -0.14921871,  0.5130252 ,  0.592646  ,  0.8787658 ,  0.4248807 ,
#        -0.21178819, -0.3434948 ,  0.19719583, -0.9422675 ,  0.3499205 ,
#        -0.08696106, -0.1923494 ,  1.0103896 , -0.34427664, -0.5359166 ,
#        -0.80220044, -0.2671562 , -0.22025932, -0.28292757,  0.18106945,


# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.optimizers import Adam

# Supongamos que X es una lista de representaciones vectoriales Word2Vec y y son las etiquetas (0 o 1)
X = X  # Aquí, X ya contiene las representaciones vectoriales de Word2Vec
y = np.array(y)

# Realizar balanceo si es necesario (oversampling)
oversampler = RandomOverSampler(random_state=42)
X, y = oversampler.fit_resample(X, y)

# Ahora, X y y tienen el mismo número de muestras

# Convertir la lista de listas X_train en una matriz NumPy
X = np.array(X)

# Definir la estrategia de validación cruzada (k=10)
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Listas para almacenar métricas de entrenamiento y validación
train_accuracy_scores = []
train_precision_scores = []
train_recall_scores = []
train_f1_scores = []

val_accuracy_scores = []
val_precision_scores = []
val_recall_scores = []
val_f1_scores = []

# Realizar la validación cruzada
for train_index, val_index in cv.split(X, y):
    train_index, val_index = train_index.tolist(), val_index.tolist()  # Convertir a listas
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Crear una red neuronal secuencial para cada fold (reiniciar el modelo)
    model = Sequential()

    # Agregar una capa de entrada con el tamaño de los vectores Word2Vec
    input_dim = len(X_train[0])  # Obtener la longitud de un vector Word2Vec
    model.add(Dense(350, activation='relu', input_dim=input_dim))
    model.add(Dropout(0.3))  # Dropout para regularización

    # Agregar una capa oculta
    model.add(Dense(228, activation='relu'))
    model.add(Dropout(0.3))  # Dropout para regularización

    # Agregar una capa de salida con una neurona y función de activación sigmoide para clasificación binaria
    model.add(Dense(1, activation='sigmoid'))

    # Compilar el modelo
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    # Utilizar EarlyStopping para detener el entrenamiento si no hay mejora
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Entrenar el modelo en los datos de entrenamiento del pliegue actual
    model.fit(X_train, y_train, epochs=1000, batch_size=200, verbose=1, validation_data=(X_val, y_val), callbacks=[early_stopping])

    # Evaluar el modelo en el conjunto de entrenamiento del pliegue actual
    y_train_pred = (model.predict(X_train) > 0.5).astype(int)

    # Calcular métricas de entrenamiento y agregarlas a las listas
    train_accuracy_scores.append(accuracy_score(y_train, y_train_pred))
    train_precision_scores.append(precision_score(y_train, y_train_pred))
    train_recall_scores.append(recall_score(y_train, y_train_pred))
    train_f1_scores.append(f1_score(y_train, y_train_pred))

    # Evaluar el modelo en el conjunto de validación
    y_val_pred = (model.predict(X_val) > 0.5).astype(int)

    # Calcular métricas de validación y agregarlas a las listas
    val_accuracy_scores.append(accuracy_score(y_val, y_val_pred))
    val_precision_scores.append(precision_score(y_val, y_val_pred))
    val_recall_scores.append(recall_score(y_val, y_val_pred))
    val_f1_scores.append(f1_score(y_val, y_val_pred))

# Calcular las métricas promediadas en entrenamiento
train_accuracy_mean = np.mean(train_accuracy_scores)
train_precision_mean = np.mean(train_precision_scores)
train_recall_mean = np.mean(train_recall_scores)
train_f1_mean = np.mean(train_f1_scores)

# Calcular las métricas promediadas en validación
val_accuracy_mean = np.mean(val_accuracy_scores)
val_precision_mean = np.mean(val_precision_scores)
val_recall_mean = np.mean(val_recall_scores)
val_f1_mean = np.mean(val_f1_scores)

# Imprimir las métricas promediadas en entrenamiento y validación
print("Entrenamiento - Accuracy: {:.2f}%".format(100 * train_accuracy_mean))
print("Entrenamiento - Precision: {:.2f}%".format(100 * train_precision_mean))
print("Entrenamiento - Recall: {:.2f}%".format(100 * train_recall_mean))
print("Entrenamiento - F1 Score: {:.2f}%".format(100 * train_f1_mean))

print("Validación - Accuracy: {:.2f}%".format(100 * val_accuracy_mean))
print("Validación - Precision: {:.2f}%".format(100 * val_precision_mean))
print("Validación - Recall: {:.2f}%".format(100 * val_recall_mean))
print("Validación - F1 Score: {:.2f}%".format(100 * val_f1_mean))
# Out:
# Epoch 1/1000
# 291/291 [==============================] - 3s 7ms/step - loss: 0.3604 - accuracy: 0.8489 - val_loss: 0.3104 - val_accuracy: 0.8721
# Epoch 2/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.3032 - accuracy: 0.8781 - val_loss: 0.2815 - val_accuracy: 0.8860
# Epoch 3/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2900 - accuracy: 0.8852 - val_loss: 0.2712 - val_accuracy: 0.8936
# Epoch 4/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2800 - accuracy: 0.8884 - val_loss: 0.2651 - val_accuracy: 0.8950
# Epoch 5/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2729 - accuracy: 0.8905 - val_loss: 0.2552 - val_accuracy: 0.8990
# Epoch 6/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2686 - accuracy: 0.8922 - val_loss: 0.2606 - val_accuracy: 0.8954
# Epoch 7/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2648 - accuracy: 0.8949 - val_loss: 0.2464 - val_accuracy: 0.9030
# Epoch 8/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2631 - accuracy: 0.8952 - val_loss: 0.2536 - val_accuracy: 0.8998
# Epoch 9/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2604 - accuracy: 0.8957 - val_loss: 0.2539 - val_accuracy: 0.8954
# Epoch 10/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2559 - accuracy: 0.8982 - val_loss: 0.2495 - val_accuracy: 0.9035
# Epoch 11/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2550 - accuracy: 0.8986 - val_loss: 0.2438 - val_accuracy: 0.9036
# Epoch 12/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2518 - accuracy: 0.9002 - val_loss: 0.2632 - val_accuracy: 0.8979
# Epoch 13/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2522 - accuracy: 0.8998 - val_loss: 0.2520 - val_accuracy: 0.9010
# Epoch 14/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2490 - accuracy: 0.9011 - val_loss: 0.2375 - val_accuracy: 0.9067
# Epoch 15/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2463 - accuracy: 0.9025 - val_loss: 0.2379 - val_accuracy: 0.9080
# Epoch 16/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2440 - accuracy: 0.9044 - val_loss: 0.2376 - val_accuracy: 0.9098
# Epoch 17/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2455 - accuracy: 0.9025 - val_loss: 0.2343 - val_accuracy: 0.9075
# Epoch 18/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2434 - accuracy: 0.9045 - val_loss: 0.2348 - val_accuracy: 0.9090
# Epoch 19/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2418 - accuracy: 0.9036 - val_loss: 0.2392 - val_accuracy: 0.9073
# Epoch 20/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2401 - accuracy: 0.9042 - val_loss: 0.2330 - val_accuracy: 0.9106
# Epoch 21/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2397 - accuracy: 0.9051 - val_loss: 0.2356 - val_accuracy: 0.9100
# Epoch 22/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2389 - accuracy: 0.9058 - val_loss: 0.2346 - val_accuracy: 0.9084
# Epoch 23/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2370 - accuracy: 0.9067 - val_loss: 0.2306 - val_accuracy: 0.9101
# Epoch 24/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2370 - accuracy: 0.9053 - val_loss: 0.2297 - val_accuracy: 0.9106
# Epoch 25/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2352 - accuracy: 0.9071 - val_loss: 0.2311 - val_accuracy: 0.9098
# Epoch 26/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2351 - accuracy: 0.9068 - val_loss: 0.2308 - val_accuracy: 0.9128
# Epoch 27/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.
1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2388 - accuracy: 0.9068 - val_loss: 0.2429 - val_accuracy: 0.9001
# Epoch 22/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2378 - accuracy: 0.9067 - val_loss: 0.2553 - val_accuracy: 0.8925
# Epoch 23/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2370 - accuracy: 0.9074 - val_loss: 0.2364 - val_accuracy: 0.9069
# Epoch 24/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2348 - accuracy: 0.9079 - val_loss: 0.2430 - val_accuracy: 0.9002
# Epoch 25/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2353 - accuracy: 0.9065 - val_loss: 0.2450 - val_accuracy: 0.9055
# Epoch 26/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2350 - accuracy: 0.9086 - val_loss: 0.2333 - val_accuracy: 0.9086
# Epoch 27/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2332 - accuracy: 0.9078 - val_loss: 0.2394 - val_accuracy: 0.9046
# Epoch 28/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2319 - accuracy: 0.9083 - val_loss: 0.2307 - val_accuracy: 0.9104
# Epoch 29/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2332 - accuracy: 0.9079 - val_loss: 0.2389 - val_accuracy: 0.9016
# Epoch 30/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2305 - accuracy: 0.9092 - val_loss: 0.2284 - val_accuracy: 0.9069
# Epoch 31/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2299 - accuracy: 0.9103 - val_loss: 0.2327 - val_accuracy: 0.9092
# Epoch 32/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2290 - accuracy: 0.9106 - val_loss: 0.2341 - val_accuracy: 0.9056
# Epoch 33/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2272 - accuracy: 0.9116 - val_loss: 0.2347 - val_accuracy: 0.9069
# Epoch 34/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2272 - accuracy: 0.9113 - val_loss: 0.2269 - val_accuracy: 0.9109
# Epoch 35/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2254 - accuracy: 0.9117 - val_loss: 0.2306 - val_accuracy: 0.9086
# Epoch 36/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2266 - accuracy: 0.9115 - val_loss: 0.2375 - val_accuracy: 0.9029
# Epoch 37/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2258 - accuracy: 0.9124 - val_loss: 0.2271 - val_accuracy: 0.9098
# Epoch 38/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2252 - accuracy: 0.9122 - val_loss: 0.2279 - val_accuracy: 0.9134
# Epoch 39/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2220 - accuracy: 0.9133 - val_loss: 0.2294 - val_accuracy: 0.9101
# Epoch 40/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2237 - accuracy: 0.9124 - val_loss: 0.2295 - val_accuracy: 0.9104
# Epoch 41/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2210 - accuracy: 0.9129 - val_loss: 0.2314 - val_accuracy: 0.9114
# Epoch 42/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2213 - accuracy: 0.9140 - val_loss: 0.2334 - val_accuracy: 0.9063
# Epoch 43/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2215 - accuracy: 0.9133 - val_loss: 0.2366 - val_accuracy: 0.9070
# Epoch 44/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2185 - accuracy: 0.9145 - val_loss: 0.2252 - val_accuracy: 0.9125
# Epoch 45/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2200 - accuracy: 0.9143 - val_loss: 0.2249 - val_accuracy: 0.9108
# Epoch 46/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2193 - accuracy: 0.9141 - val_loss: 0.2263 - val_accuracy: 0.9098
# Epoch 47/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2176 - accuracy: 0.9148 - val_loss: 0.2242 - val_accuracy: 0.9115
# Epoch 48/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2189 - accuracy: 0.9146 - val_loss: 0.2222 - val_accuracy: 0.9146
# Epoch 49/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2195 - accuracy: 0.9134 - val_loss: 0.2252 - val_accuracy: 0.9117
# Epoch 50/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2176 - accuracy: 0.9149 - val_loss: 0.2272 - val_accuracy: 0.9084
# Epoch 51/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2159 - accuracy: 0.9146 - val_loss: 0.2236 - val_accuracy: 0.9115
# Epoch 52/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2152 - accuracy: 0.9160 - val_loss: 0.2286 - val_accuracy: 0.9095
# Epoch 53/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2164 - accuracy: 0.9148 - val_loss: 0.2257 - val_accuracy: 0.9126
# Epoch 54/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2155 - accuracy: 0.9164 - val_loss: 0.2235 - val_accuracy: 0.9168
# Epoch 55/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2138 - accuracy: 0.9158 - val_loss: 0.2246 - val_accuracy: 0.9103
# Epoch 56/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2151 - accuracy: 0.9157 - val_loss: 0.2207 - val_accuracy: 0.9108
# Epoch 57/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2138 - accuracy: 0.9158 - val_loss: 0.2188 - val_accuracy: 0.9128
# Epoch 58/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2132 - accuracy: 0.9162 - val_loss: 0.2207 - val_accuracy: 0.9157
# Epoch 59/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2134 - accuracy: 0.9162 - val_loss: 0.2184 - val_accuracy: 0.9157
# Epoch 60/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2140 - accuracy: 0.9162 - val_loss: 0.2245 - val_accuracy: 0.9121
# Epoch 61/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2116 - accuracy: 0.9176 - val_loss: 0.2216 - val_accuracy: 0.9134
# Epoch 62/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2119 - accuracy: 0.9173 - val_loss: 0.2204 - val_accuracy: 0.9140
# Epoch 63/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2123 - accuracy: 0.9174 - val_loss: 0.2249 - val_accuracy: 0.9154
# Epoch 64/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2103 - accuracy: 0.9172 - val_loss: 0.2196 - val_accuracy: 0.9160
# Epoch 65/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2095 - accuracy: 0.9180 - val_loss: 0.2243 - val_accuracy: 0.9118
# Epoch 66/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2089 - accuracy: 0.9180 - val_loss: 0.2239 - val_accuracy: 0.9103
# Epoch 67/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2085 - accuracy: 0.9179 - val_loss: 0.2221 - val_accuracy: 0.9114
# Epoch 68/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2084 - accuracy: 0.9189 - val_loss: 0.2189 - val_accuracy: 0.9169
# Epoch 69/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2069 - accuracy: 0.9193 - val_loss: 0.2218 - val_accuracy: 0.9123
# 1819/1819 [==============================] - 3s 2ms/step
# 203/203 [==============================] - 0s 2ms/step
# Epoch 1/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.3599 - accuracy: 0.8515 - val_loss: 0.2882 - val_accuracy: 0.8886
# Epoch 2/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.3000 - accuracy: 0.8792 - val_loss: 0.2692 - val_accuracy: 0.8914
# Epoch 3/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2862 - accuracy: 0.8859 - val_loss: 0.2613 - val_accuracy: 0.8991
# Epoch 4/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2806 - accuracy: 0.8878 - val_loss: 0.2541 - val_accuracy: 0.9016
# Epoch 5/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2726 - accuracy: 0.8923 - val_loss: 0.2559 - val_accuracy: 0.9002
# Epoch 6/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2698 - accuracy: 0.8938 - val_loss: 0.2560 - val_accuracy: 0.8967
# Epoch 7/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2672 - accuracy: 0.8950 - val_loss: 0.2610 - val_accuracy: 0.8973
# Epoch 8/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2606 - accuracy: 0.8975 - val_loss: 0.2611 - val_accuracy: 0.8927
# Epoch 9/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2595 - accuracy: 0.8968 - val_loss: 0.2591 - val_accuracy: 0.8917
# Epoch 10/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2559 - accuracy: 0.8997 - val_loss: 0.2431 - val_accuracy: 0.9047
# Epoch 11/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2553 - accuracy: 0.9001 - val_loss: 0.2502 - val_accuracy: 0.8982
# Epoch 12/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2544 - accuracy: 0.9002 - val_loss: 0.2433 - val_accuracy: 0.9060
# Epoch 13/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2518 - accuracy: 0.9000 - val_loss: 0.2381 - val_accuracy: 0.9050
# Epoch 14/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2485 - accuracy: 0.9022 - val_loss: 0.2677 - val_accuracy: 0.8919
# Epoch 15/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2471 - accuracy: 0.9033 - val_loss: 0.2417 - val_accuracy: 0.9039
# Epoch 16/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2478 - accuracy: 0.9018 - val_loss: 0.2398 - val_accuracy: 0.9032
# Epoch 17/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2441 - accuracy: 0.9038 - val_loss: 0.2333 - val_accuracy: 0.9104
# Epoch 18/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2443 - accuracy: 0.9041 - val_loss: 0.2317 - val_accuracy: 0.9075
# Epoch 19/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2415 - accuracy: 0.9054 - val_loss: 0.2348 - val_accuracy: 0.9066
# Epoch 20/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2405 - accuracy: 0.9043 - val_loss: 0.2339 - val_accuracy: 0.9066
# Epoch 21/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2394 - accuracy: 0.9059 - val_loss: 0.2280 - val_accuracy: 0.9098
# Epoch 22/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2405 - accuracy: 0.9047 - val_loss: 0.2353 - val_accuracy: 0.9061
# Epoch 23/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2387 - accuracy: 0.9063 - val_loss: 0.2323 - val_accuracy: 0.9084
# Epoch 24/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2388 - accuracy: 0.9060 - val_loss: 0.2319 - val_accuracy: 0.9090
# Epoch 25/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2382 - accuracy: 0.9055 - val_loss: 0.2272 - val_accuracy: 0.9097
# Epoch 26/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2361 - accuracy: 0.9065 - val_loss: 0.2281 - val_accuracy: 0.9100
# Epoch 27/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2352 - accuracy: 0.9074 - val_loss: 0.2257 - val_accuracy: 0.9098
# Epoch 28/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2334 - accuracy: 0.9085 - val_loss: 0.2334 - val_accuracy: 0.9087
# Epoch 29/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2328 - accuracy: 0.9084 - val_loss: 0.2255 - val_accuracy: 0.9114
# Epoch 30/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2338 - accuracy: 0.9078 - val_loss: 0.2408 - val_accuracy: 0.9019
# Epoch 31/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2306 - accuracy: 0.9092 - val_loss: 0.2243 - val_accuracy: 0.9095
# Epoch 32/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2311 - accuracy: 0.9095 - val_loss: 0.2258 - val_accuracy: 0.9090
# Epoch 33/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2317 - accuracy: 0.9086 - val_loss: 0.2231 - val_accuracy: 0.9094
# Epoch 34/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2295 - accuracy: 0.9104 - val_loss: 0.2216 - val_accuracy: 0.9125
# Epoch 35/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2293 - accuracy: 0.9087 - val_loss: 0.2260 - val_accuracy: 0.9131
# Epoch 36/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2284 - accuracy: 0.9102 - val_loss: 0.2244 - val_accuracy: 0.9108
# Epoch 37/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2273 - accuracy: 0.9103 - val_loss: 0.2217 - val_accuracy: 0.9143
# Epoch 38/1000
# ...
# Epoch 48/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2204 - accuracy: 0.9136 - val_loss: 0.2178 - val_accuracy: 0.9110
# Epoch 49/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2197 - accuracy: 0.9151 - val_loss: 0.2157 - val_accuracy: 0.9144
# Epoch 50/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2190 - accuracy: 0.9146 - val_loss: 0.2204 - val_accuracy: 0.9121
# Epoch 51/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2178 - accuracy: 0.9144 - val_loss: 0.2202 - val_accuracy: 0.9131
# Epoch 52/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2171 - accuracy: 0.9166 - val_loss: 0.2168 - val_accuracy: 0.9141
# Epoch 53/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2162 - accuracy: 0.9150 - val_loss: 0.2185 - val_accuracy: 0.9124
# Epoch 54/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2180 - accuracy: 0.9136 - val_loss: 0.2163 - val_accuracy: 0.9124
# Epoch 55/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2186 - accuracy: 0.9142 - val_loss: 0.2175 - val_accuracy: 0.9114
# Epoch 56/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2161 - accuracy: 0.9154 - val_loss: 0.2168 - val_accuracy: 0.9144
# Epoch 57/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2168 - accuracy: 0.9157 - val_loss: 0.2174 - val_accuracy: 0.9129
# Epoch 58/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2148 - accuracy: 0.9158 - val_loss: 0.2128 - val_accuracy: 0.9168
# Epoch 59/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2141 - accuracy: 0.9162 - val_loss: 0.2210 - val_accuracy: 0.9134
# Epoch 60/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2143 - accuracy: 0.9157 - val_loss: 0.2155 - val_accuracy: 0.9146
# Epoch 61/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2146 - accuracy: 0.9166 - val_loss: 0.2156 - val_accuracy: 0.9135
# Epoch 62/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2132 - accuracy: 0.9179 - val_loss: 0.2175 - val_accuracy: 0.9126
# Epoch 63/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2135 - accuracy: 0.9158 - val_loss: 0.2134 - val_accuracy: 0.9154
# Epoch 64/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2121 - accuracy: 0.9170 - val_loss: 0.2146 - val_accuracy: 0.9141
# Epoch 65/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2129 - accuracy: 0.9174 - val_loss: 0.2199 - val_accuracy: 0.9134
# Epoch 66/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2115 - accuracy: 0.9164 - val_loss: 0.2177 - val_accuracy: 0.9140
# Epoch 67/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2120 - accuracy: 0.9169 - val_loss: 0.2153 - val_accuracy: 0.9143
# Epoch 68/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2103 - accuracy: 0.9182 - val_loss: 0.2139 - val_accuracy: 0.9140
# 1819/1819 [==============================] - 3s 1ms/step
# 202/202 [==============================] - 0s 1ms/step
# Epoch 1/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.3592 - accuracy: 0.8520 - val_loss: 0.3086 - val_accuracy: 0.8773
# Epoch 2/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2992 - accuracy: 0.8805 - val_loss: 0.2912 - val_accuracy: 0.8852
# Epoch 3/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2877 - accuracy: 0.8851 - val_loss: 0.2833 - val_accuracy: 0.8917
# Epoch 4/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2774 - accuracy: 0.8897 - val_loss: 0.2731 - val_accuracy: 0.8950
# Epoch 5/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2716 - accuracy: 0.8926 - val_loss: 0.2694 - val_accuracy: 0.8946
# Epoch 6/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2696 - accuracy: 0.8928 - val_loss: 0.2709 - val_accuracy: 0.8940
# Epoch 7/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2613 - accuracy: 0.8967 - val_loss: 0.2617 - val_accuracy: 0.8970
# Epoch 8/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2614 - accuracy: 0.8975 - val_loss: 0.2765 - val_accuracy: 0.8912
# Epoch 9/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2580 - accuracy: 0.8975 - val_loss: 0.2586 - val_accuracy: 0.8965
# Epoch 10/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2563 - accuracy: 0.8988 - val_loss: 0.2605 - val_accuracy: 0.8974
# Epoch 11/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2525 - accuracy: 0.9012 - val_loss: 0.2564 - val_accuracy: 0.9018
# Epoch 12/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2517 - accuracy: 0.9008 - val_loss: 0.2538 - val_accuracy: 0.8990
# Epoch 13/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2496 - accuracy: 0.9019 - val_loss: 0.2532 - val_accuracy: 0.8994
# Epoch 14/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2482 - accuracy: 0.9016 - val_loss: 0.2564 - val_accuracy: 0.8985
# Epoch 15/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2444 - accuracy: 0.9032 - val_loss: 0.2475 - val_accuracy: 0.9032
# Epoch 16/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2450 - accuracy: 0.9033 - val_loss: 0.2501 - val_accuracy: 0.9013
# Epoch 17/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2471 - accuracy: 0.9023 - val_loss: 0.2458 - val_accuracy: 0.9053
# Epoch 18/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2413 - accuracy: 0.9046 - val_loss: 0.2511 - val_accuracy: 0.9021
# Epoch 19/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2413 - accuracy: 0.9045 - val_loss: 0.2573 - val_accuracy: 0.8960
# Epoch 20/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2404 - accuracy: 0.9063 - val_loss: 0.2481 - val_accuracy: 0.9028
# Epoch 21/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2375 - accuracy: 0.9059 - val_loss: 0.2459 - val_accuracy: 0.9035
# Epoch 22/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2367 - accuracy: 0.9061 - val_loss: 0.2405 - val_accuracy: 0.9058
# Epoch 23/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2348 - accuracy: 0.9070 - val_loss: 0.2393 - val_accuracy: 0.9073
# Epoch 24/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2363 - accuracy: 0.9064 - val_loss: 0.2425 - val_accuracy: 0.9036
# Epoch 25/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2359 - accuracy: 0.9072 - val_loss: 0.2382 - val_accuracy: 0.9092
# Epoch 26/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2347 - accuracy: 0.9072 - val_loss: 0.2405 - val_accuracy: 0.9086
# Epoch 27/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2339 - accuracy: 0.9078 - val_loss: 0.2403 - val_accuracy: 0.9072
# Epoch 28/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2324 - accuracy: 0.9082 - val_loss: 0.2420 - val_accuracy: 0.9067
# Epoch 29/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2313 - accuracy: 0.9097 - val_loss: 0.2412 - val_accuracy: 0.9058
# Epoch 30/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2302 - accuracy: 0.9106 - val_loss: 0.2351 - val_accuracy: 0.9083
# Epoch 31/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2296 - accuracy: 0.9096 - val_loss: 0.2372 - val_accuracy: 0.9059
# Epoch 32/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2309 - accuracy: 0.9101 - val_loss: 0.2424 - val_accuracy: 0.9059
# Epoch 33/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2302 - accuracy: 0.9095 - val_loss: 0.2382 - val_accuracy: 0.9070
# Epoch 34/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2275 - accuracy: 0.9099 - val_loss: 0.2436 - val_accuracy: 0.9042
# Epoch 35/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2281 - accuracy: 0.9109 - val_loss: 0.2363 - val_accuracy: 0.9073
# Epoch 36/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2263 - accuracy: 0.9107 - val_loss: 0.2354 - val_accuracy: 0.9072
# Epoch 37/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2258 - accuracy: 0.9119 - val_loss: 0.2369 - val_accuracy: 0.9095
# Epoch 38/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2273 - accuracy: 0.9104 - val_loss: 0.2386 - val_accuracy: 0.9066
# Epoch 39/1000
# 291/291 [==============================] - 2s 5ms/step - loss: 0.2236 - accuracy: 0.9123 - val_loss: 0.2321 - val_accuracy: 0.9076
# Epoch 40/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2238 - accuracy: 0.9117 - val_loss: 0.2334 - val_accuracy: 0.9087
# Epoch 41/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2222 - accuracy: 0.9124 - val_loss: 0.2364 - val_accuracy: 0.9062
# Epoch 42/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2218 - accuracy: 0.9131 - val_loss: 0.2387 - val_accuracy: 0.9056
# Epoch 43/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2219 - accuracy: 0.9131 - val_loss: 0.2336 - val_accuracy: 0.9092
# Epoch 44/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2227 - accuracy: 0.9126 - val_loss: 0.2302 - val_accuracy: 0.9089
# Epoch 45/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2188 - accuracy: 0.9156 - val_loss: 0.2366 - val_accuracy: 0.9072
# Epoch 46/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2202 - accuracy: 0.9139 - val_loss: 0.2316 - val_accuracy: 0.9112
# Epoch 47/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2180 - accuracy: 0.9148 - val_loss: 0.2307 - val_accuracy: 0.9093
# Epoch 48/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2186 - accuracy: 0.9141 - val_loss: 0.2326 - val_accuracy: 0.9092
# Epoch 49/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2185 - accuracy: 0.9144 - val_loss: 0.2268 - val_accuracy: 0.9110
# Epoch 50/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2175 - accuracy: 0.9148 - val_loss: 0.2289 - val_accuracy: 0.9104
# Epoch 51/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2183 - accuracy: 0.9149 - val_loss: 0.2323 - val_accuracy: 0.9110
# Epoch 52/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2158 - accuracy: 0.9161 - val_loss: 0.2340 - val_accuracy: 0.9076
# Epoch 53/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2165 - accuracy: 0.9154 - val_loss: 0.2304 - val_accuracy: 0.9115
# Epoch 54/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2146 - accuracy: 0.9165 - val_loss: 0.2373 - val_accuracy: 0.9055
# Epoch 55/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2147 - accuracy: 0.9163 - val_loss: 0.2310 - val_accuracy: 0.9104
# Epoch 56/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2147 - accuracy: 0.9156 - val_loss: 0.2261 - val_accuracy: 0.9135
# Epoch 57/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2148 - accuracy: 0.9148 - val_loss: 0.2296 - val_accuracy: 0.9146
# Epoch 58/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2159 - accuracy: 0.9148 - val_loss: 0.2300 - val_accuracy: 0.9086
# Epoch 59/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2122 - accuracy: 0.9172 - val_loss: 0.2304 - val_accuracy: 0.9107
# Epoch 60/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2130 - accuracy: 0.9167 - val_loss: 0.2302 - val_accuracy: 0.9114
# Epoch 61/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2143 - accuracy: 0.9154 - val_loss: 0.2288 - val_accuracy: 0.9123
# Epoch 62/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2111 - accuracy: 0.9174 - val_loss: 0.2316 - val_accuracy: 0.9106
# Epoch 63/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2129 - accuracy: 0.9161 - val_loss: 0.2275 - val_accuracy: 0.9134
# Epoch 64/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2104 - accuracy: 0.9177 - val_loss: 0.2259 - val_accuracy: 0.9129
# Epoch 65/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2108 - accuracy: 0.9168 - val_loss: 0.2306 - val_accuracy: 0.9120
# Epoch 66/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2100 - accuracy: 0.9182 - val_loss: 0.2218 - val_accuracy: 0.9155
# Epoch 67/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2107 - accuracy: 0.9162 - val_loss: 0.2269 - val_accuracy: 0.9104
# Epoch 68/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2098 - accuracy: 0.9183 - val_loss: 0.2279 - val_accuracy: 0.9109
# Epoch 69/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2086 - accuracy: 0.9182 - val_loss: 0.2204 - val_accuracy: 0.9154
# Epoch 70/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2094 - accuracy: 0.9170 - val_loss: 0.2242 - val_accuracy: 0.9118
# Epoch 71/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2075 - accuracy: 0.9187 - val_loss: 0.2244 - val_accuracy: 0.9118
# Epoch 72/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2076 - accuracy: 0.9183 - val_loss: 0.2288 - val_accuracy: 0.9148
# Epoch 73/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2073 - accuracy: 0.9200 - val_loss: 0.2251 - val_accuracy: 0.9148
# Epoch 74/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2062 - accuracy: 0.9200 - val_loss: 0.2248 - val_accuracy: 0.9124
# Epoch 75/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2059 - accuracy: 0.9188 - val_loss: 0.2210 - val_accuracy: 0.9154
# Epoch 76/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2051 - accuracy: 0.9205 - val_loss: 0.2181 - val_accuracy: 0.9165
# Epoch 77/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2064 - accuracy: 0.9187 - val_loss: 0.2221 - val_accuracy: 0.9124
# Epoch 78/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2068 - accuracy: 0.9196 - val_loss: 0.2221 - val_accuracy: 0.9134
# Epoch 79/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2042 - accuracy: 0.9209 - val_loss: 0.2277 - val_accuracy: 0.9120
# Epoch 80/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2042 - accuracy: 0.9208 - val_loss: 0.2254 - val_accuracy: 0.9141
# Epoch 81/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2045 - accuracy: 0.9199 - val_loss: 0.2235 - val_accuracy: 0.9120
# Epoch 82/1000
# 291/291 [==============================] - 2s 6ms/step - loss: 0.2041 - accuracy: 0.9191 - val_loss: 0.2234 - val_accuracy: 0.9149
# Epoch 83/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2042 - accuracy: 0.9205 - val_loss: 0.2232 - val_accuracy: 0.9152
# Epoch 84/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2017 - accuracy: 0.9212 - val_loss: 0.2247 - val_accuracy: 0.9135
# Epoch 85/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2025 - accuracy: 0.9208 - val_loss: 0.2235 - val_accuracy: 0.9151
# Epoch 86/1000
# 291/291 [==============================] - 2s 7ms/step - loss: 0.2031 - accuracy: 0.9202 - val_loss: 0.2232 - val_accuracy: 0.9126
# 1819/1819 [==============================] - 4s 2ms/step
# 202/202 [==============================] - 0s 2ms/step
# Entrenamiento - Accuracy: 92.65%
# Entrenamiento - Precision: 95.16%
# Entrenamiento - Recall: 89.86%
# Entrenamiento - F1 Score: 92.43%
# Validación - Accuracy: 91.84%
# Validación - Precision: 94.33%
# Validación - Recall: 89.04%
# Validación - F1 Score: 91.60%

# %%
# Imprimir las métricas promediadas en entrenamiento y validación
print("Entrenamiento - Accuracy: {:.2f}%".format(100 * train_accuracy_mean))
print("Entrenamiento - Precision: {:.2f}%".format(100 * train_precision_mean))
print("Entrenamiento - Recall: {:.2f}%".format(100 * train_recall_mean))
print("Entrenamiento - F1 Score: {:.2f}%".format(100 * train_f1_mean))

print("Validación - Accuracy: {:.2f}%".format(100 * val_accuracy_mean))
print("Validación - Precision: {:.2f}%".format(100 * val_precision_mean))
print("Validación - Recall: {:.2f}%".format(100 * val_recall_mean))
print("Validación - F1 Score: {:.2f}%".format(100 * val_f1_mean))
# Out:
# Entrenamiento - Accuracy: 92.65%
# Entrenamiento - Precision: 95.16%
# Entrenamiento - Recall: 89.86%
# Entrenamiento - F1 Score: 92.43%
# Validación - Accuracy: 91.84%
# Validación - Precision: 94.33%
# Validación - Recall: 89.04%
# Validación - F1 Score: 91.60%

# %% [markdown]
# # Guardar el modelo

# %%
import joblib
import os
# Directorio para guardar modelos entrenados
model_dir = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs ansiedad)'
model_filename = 'TWEETS_ansiedad (RN-Word2Vec).pkl'
model_path_p = os.path.join(model_dir, model_filename)

# Guardar el modelo entrenado
joblib.dump(model, model_path_p)
# Out:
# ['/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs ansiedad)/TWEETS_ansiedad (RN-Word2Vec).pkl']

# %% [markdown]
# # Evaluación

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Función para calcular el vector promedio de un documento
def document_vector(tokens, modeWl):
    # Filtrar palabras que no están en el modelo Word2Vec
    tokens = [token for token in tokens if token in modelW.wv.key_to_index]
    if len(tokens) == 0:
        return np.zeros(modelW.vector_size)
    return np.mean([modelW.wv[token] for token in tokens], axis=0)

# Aplicar transformaciones al conjunto de pruebas
data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(removeHTML)
data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(clean)
data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(extractTerms)

# Obtener representaciones Word2Vec para el conjunto de pruebas
X_test_word2vec = [document_vector(tokens, modelW) for tokens in data_test['TWEET_TEXT']]

# Crear el conjunto de pruebas
X_test = np.array(X_test_word2vec)
y_test = data_test['trastorno'].values

# Predicciones en el conjunto de pruebas
y_test_pred = (model.predict(X_test) > 0.5).astype(int)  # Aquí asumimos un umbral de 0.5 para la clasificación

# Calcular precisión en el conjunto de pruebas
precision_test = precision_score(y_test, y_test_pred)

# Calcular exhaustividad (recall) en el conjunto de pruebas
recall_test = recall_score(y_test, y_test_pred)

# Calcular puntuación F1 en el conjunto de pruebas
f1_test = f1_score(y_test, y_test_pred)

# Calcular exactitud en el conjunto de pruebas (opcional)
accuracy_test = accuracy_score(y_test, y_test_pred)

# Imprimir métricas de evaluación con el símbolo '%'
print("Precisión: {:.2f}%".format(precision_test * 100))
print("Exhaustividad (Recall): {:.2f}%".format(recall_test * 100))
print("Puntuación F1: {:.2f}%".format(f1_test * 100))
print("Exactitud: {:.2f}%".format(accuracy_test * 100))
# Out:
# 871/871 [==============================] - 2s 2ms/step
# Precisión: 93.47%
# Exhaustividad (Recall): 89.74%
# Puntuación F1: 91.57%
# Exactitud: 91.72%

# %% [markdown]
# # MATRIZ DE CONFUSIÓN

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)

# Obtiene la matriz de confusión. Las filas corresponden a las clases reales,
umbral = 0.5  # Puedes ajustar este umbral según tus necesidades
y_pred_binario = (y_pred > umbral).astype(int)

# Calcular la matriz de confusión con las etiquetas binarias
cm = confusion_matrix(y_test, y_pred_binario)
prop_real = np.sum(y_test)/len(y_test)
prop_etiqutados = (cm[0,1]+cm[1,1])/len(y_test)

print("Matriz de confusión: \n\n", cm, "\n")
print('Proporción de comentarios positivos: %.2f'% prop_real)
print('Proporción de comentarios positivos etiquetados: %.2f'% prop_etiqutados)
# Out:
# 871/871 [==============================] - 2s 2ms/step
# Matriz de confusión:
#
#  [[13019   875]
#  [ 1432 12527]]
#
# Proporción de comentarios positivos: 0.50
# Proporción de comentarios positivos etiquetados: 0.48

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una figura para la matriz de confusión
plt.figure(figsize=(8, 6))

# Crear una matriz de confusión usando el heatmap de Seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['0', '1'], yticklabels=['0', '1'])

# Etiquetas y título
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Modelo Entrenado

# %%
import joblib
import numpy as np

# Cargar el modelo entrenado
model_path = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs ansiedad)/TWEETS_ansiedad (RN-Word2Vec).pkl'
loaded_model = joblib.load(model_path)

# Texto de ejemplo para predecir
new_tweet = "ok maldecir niño golpear niño menospreciar amenazar niño todos locos necesito ayuda"

# Preprocesamiento del texto
new_tweet_cleaned = clean(removeHTML(new_tweet))
new_tweet_extracted = extractTerms(new_tweet_cleaned)
new_tweet_combined = ' '.join(new_tweet_extracted)

# modelW = Word2Vec(data_train['TWEET_TEXT'], vector_size=100, window=5, min_count=1, sg=0)
def document_vector(tokens, modelW):
    # Filtrar palabras que no están en el modelo
    tokens = [token for token in tokens if token in modelW.wv.key_to_index]
    if len(tokens) == 0:
        return np.zeros(modelW.vector_size)
    return np.mean([modelW.wv[token] for token in tokens], axis=0)

# Supongamos que 'word2vec_model' es tu modelo Word2Vec entrenado previamente
new_tweet_word2vec = document_vector(new_tweet_extracted, modelW)

# Redimensionar new_tweet_word2vec a una matriz 2D
new_tweet_word2vec = np.array([new_tweet_word2vec])

# Hacer la predicción y obtener las probabilidades de predicción
proba_prediction = loaded_model.predict(new_tweet_word2vec)

# Verificar la forma de proba_prediction
if proba_prediction.shape[1] == 1:
    # Solo una probabilidad en proba_prediction, se asume que es la probabilidad de clase 1
    control_prob = 1 - proba_prediction[0][0]  # Probabilidad de ser control
    depresion_prob = proba_prediction[0][0]  # Probabilidad de ser depresión
else:
    # Hay dos probabilidades en proba_prediction (clases binarias)
    control_prob = 1 - proba_prediction[0][0]  # Probabilidad de ser control
    depresion_prob = proba_prediction[0][0]  # Probabilidad de ser ansiedad

# Las probabilidades de clase están en 'control_prob' y 'depresion_prob'

# Imprimir el resultado basado en las probabilidades
print(new_tweet)
print('------------------------------------------------------------------')
if depresion_prob > control_prob:
    print("Este tweet es de ansiedad")
    print("Probabilidad de que el tweet sea de ansiedad: {:.2f}%".format(depresion_prob * 100))
else:
    print("Este tweet No es de ansiedad")
    print("Probabilidad de que el tweet no sea de ansiedad: {:.2f}%".format(control_prob * 100))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# ok maldecir niño golpear niño menospreciar amenazar niño todos locos necesito ayuda
# ------------------------------------------------------------------
# Este tweet es de ansiedad
# Probabilidad de que el tweet sea de ansiedad: 99.99%

# %% [markdown]
# en compración con la implementación de la tecnica de la BoW y TIDF la red neuronal puedo entrenar con el conjunto de datos completo ya que al no ser un matriz dispersa ya que cada palabra es representada por un vector de 300 dimenciones la matriz resultante no consumir tanto requesitos computacionales, tambien la configuración de la red neuronal aumento el numero de neutoran de las capas ocultas, el numero de lotes y el numero de epoca resultando a un entrenamiento sastifactorio.
#
# Además, se observa que la caracterización de palabras con la tecnica de word embedding es un buen metodo ya que no crea vectores dispersos y encompración a los vectores de BOW y TFIDF que las palabras estan separadad a la misma distancia perdiendo con esto el valor semantico de las palabras en el conjunto de entrenamiento, mientras que los word embedding tiene  en cuenta el valor semantico de las palabras ya que dependiendo del conjuto de datos y del modelo preentrenado las palabras estan más cercas de unas dependiendo del contexto.
#
# al implementar un modelo preentreado como Word2Vec con millones de palabras, este modelo de forma no supervisada encuentra patrones internos y agrupando cierta palabras entre más similitudes tendan dentro del contento entreano de la base de datos obteniendo un conjuto de entrenamiento valioso ya que tiene en cuenta el contexto de la base datos a la hora de crear el arreglo vectorial para el entrenamiento del modelo.
#
# una desventanja que meneja la implementación de este modelo es que al crear un arreglo vectorial de cada palabra presente el vocabulario de entrenamiento se crea matrices muy grandes y complejas haciendo que el proceso de entrenamiento sea mucho más complejo y demorado.
