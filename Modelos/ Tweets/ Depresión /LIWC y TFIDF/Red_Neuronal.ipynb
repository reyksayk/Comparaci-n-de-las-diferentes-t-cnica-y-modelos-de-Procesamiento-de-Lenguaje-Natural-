# %%
# !pip install liwc
# !pip install nltk
# !pip install spacy
# !python -m spacy download es_core_news_sm
# !pip install -U imbalanced-learn
# !pip install pyspellchecker

# %%
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Oculta warnings
import warnings
warnings.simplefilter('ignore')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # **Leer LIWC diccionario - Español**

# %%
import liwc

# %%
liwcPath= r'/content/drive/MyDrive/Experimentación Python Tesis /Diccionarios español/Spanish_LIWC2007_Dictionary.dic'
parse, category_names = liwc.load_token_parser(liwcPath)
print(f'Categorias del diccionario: {category_names}')
# Out:
# Categorias del diccionario: ['Funct', 'TotPron', 'PronPer', 'Yo', 'Nosotro', 'TuUtd', 'ElElla', 'Ellos', 'PronImp', 'Articulo', 'Verbos', 'VerbAux', 'Pasado', 'Present', 'Futuro', 'Adverb', 'Prepos', 'Conjunc', 'Negacio', 'Cuantif', 'Numeros', 'Maldec', 'verbYO', 'verbTU', 'verbNOS', 'verbosEL', 'verbELLOS', 'Subjuntiv', 'VosUtds', 'formal', 'informal', 'verbVos', 'Social', 'Familia', 'Amigos', 'Humanos', 'Afect', 'EmoPos', 'EmoNeg', 'Ansiedad', 'Enfado', 'Triste', 'MecCog', 'Insight', 'Causa', 'Discrep', 'Tentat', 'Certeza', 'Inhib', 'Incl', 'Excl', 'Percept', 'Ver', 'Oir', 'Sentir', 'Biolog', 'Cuerpo', 'Salud', 'Sexual', 'Ingerir', 'Relativ', 'Movim', 'Espacio', 'Tiempo', 'Trabajo', 'Logro', 'Placer', 'Hogar', 'Dinero', 'Relig', 'Muerte', 'Asentir', 'NoFluen', 'Relleno']

# %% [markdown]
# # CARGAR DATOS

# %% [markdown]
# **DATOS DE ENTRENAMIENTO**
#
# la columna de trastornos indica si el TWEET es de una persona con depresión o es de control.
#
#
# **control**:     0
#
# **depresión**:   1

# %%
ruta_archivo_entrenamiento = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs depresión)/train.csv'
data_train = pd.read_csv(ruta_archivo_entrenamiento, sep=',')
#data_train = data.iloc[:num_docs, :]
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263950 entries, 0 to 263949
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     263950 non-null  object
#  1   TWEET_ID    263920 non-null  float64
#  2   TWEET_TEXT  263841 non-null  object
#  3   trastorno   263950 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.1+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  RT @Julii_AKD: por qué a la mayoría de las pib...
# 1       6  2.147484e+09                  Empezar un 2017 sintiéndote solo.
# 2     279  2.147484e+09  Ah mirá que lindo como me escrachan en Instagr...
# 3     518  2.147484e+09                            https://t.co/hC3rULMb1P
# 4     301  2.147484e+09  Tu sigue con él, cumple tu deber, muy pronto v...
# 5     177  2.147484e+09                  @Sebbasrp deje dormir al prójimo.
# 6      45  2.147484e+09  RT @Crookedgirlx: no quiero vivir más, estoy c...
# 7      29  2.147484e+09  RT @Esunbreakable: Me da un poquito de vergüen...
# 8     388  2.147484e+09  Venezuela-related Designation https://t.co/IOZ...
# 9      31  2.147484e+09  Tengo muchas ganas de escribirte para decirte ...
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          1
# 8          0
# 9          1

# %%
# Verificar si hay filas nulas o vacías en la columna 'TWEET_TEXT'
null_values = data_train['TWEET_TEXT'].isnull().sum()

# Imprimir el número de filas nulas o vacías
print("Número de filas nulas o vacías en la columna 'TWEET_TEXT':", null_values)
# Out:
# Número de filas nulas o vacías en la columna 'TWEET_TEXT': 109

# %%
data_train.dropna(subset=['TWEET_TEXT'], inplace=True)

# Verificar si hay filas nulas o vacías en la columna 'TWEET_TEXT'
null_values = data_train['TWEET_TEXT'].isnull().sum()

# Imprimir el número de filas nulas o vacías
print("Número de filas nulas o vacías en la columna 'TWEET_TEXT':", null_values)
data_train.info()
# Out:
# Número de filas nulas o vacías en la columna 'TWEET_TEXT': 0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263841 entries, 0 to 263949
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     263841 non-null  object
#  1   TWEET_ID    263841 non-null  float64
#  2   TWEET_TEXT  263841 non-null  object
#  3   trastorno   263841 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 10.1+ MB

# %% [markdown]
# # **limpiar Dataset**

# %%
import re
import string


def removeHTML(text):
    if isinstance(text, str):  # Verificar si es de tipo string
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, '', text)
        return cleantext
    else:
        return text  # Devolver el valor original si no es de tipo string

def clean(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub(r'https', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'(https?://)?[a-zA-Z0-9]+\.[a-zA-Z0-9]+\S*', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'\b[A-Z][a-z]+\b', '', text)
    text = re.sub(r'[^\w\s]+', '', text)
    text = re.sub(r'\b\w{1,2}\b|\d+', '', text)
    emojis = re.findall(r'[^\w\s,]', text)
    cleaned_emojis = [emoji for emoji in emojis if emoji not in ['@', '#', '/', '?','¿','.','…','"',':','“','!','¡','°','-',"‘",'’',
                                                                  '=',';','(',')',"'","'",'&','€','%','$','*','+','|', '”','🇦','🇷',',',
                                                                  ', ','—','«',' »','»','« ','[, ]','[,]',',',', ','',' ',' ♀',' 🏽']]
    for emoji in cleaned_emojis:
        text = text.replace(emoji, '')
    return text

# %%
data_train['TWEET_TEXT'] = data_train.TWEET_TEXT.apply(lambda x : removeHTML(x))
data_train['TWEET_TEXT'] = data_train.TWEET_TEXT.apply(lambda x : clean(x))

# %%
data_train['TWEET_TEXT']
# Out:
# 0           juliiakd  por qué   mayoría  las pibas  les ...
# 1                               empezar   sintiéndote solo
# 2          mirá que lindo como  escrachan  instagram  ma...
# 3
# 4          sigue con   cumple  deber  muy pronto vestida...
#                                 ...
# 263945             por que  toco  gato madrugador   camada
# 263946     lamatanza     presidente del  centroindustria...
# 263947             tengo una relación toxica conmigo mismo
# 263948                                   suena convincente
# 263949    hora  dormir              dijo llorando   cuar...
# Name: TWEET_TEXT, Length: 263950, dtype: object

# %% [markdown]
# **Remover Stopword**

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')  #Solamente se ha de descargar la primera vez.
stopwords_en = nltk.corpus.stopwords.words('spanish')   # Extrae las stopwords en español
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def Stopword(text):
  token_text = nltk.word_tokenize(text)
  remover_palab = [word for word in token_text if word not in stopwords_en]
  join_text = ' '.join(remover_palab)
  return join_text

# %%
data_train['TWEET_TEXT'] = data_train.TWEET_TEXT.apply(lambda x : Stopword(x))

# %%
data_train.head(10)
# Out:
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  juliiakd mayoría pibas gusta tener piernas gra...
# 1       6  2.147484e+09                           empezar sintiéndote solo
# 2     279  2.147484e+09           mirá lindo escrachan instagram magnifico
# 3     518  2.147484e+09
# 4     301  2.147484e+09  sigue cumple deber pronto vestida novia estarásss
# 5     177  2.147484e+09                       sebbasrp deje dormir prójimo
# 6      45  2.147484e+09                  crookedgirlx quiero vivir cansada
# 7      29  2.147484e+09  esunbreakable poquito vergüenza alguien quiere...
# 8     388  2.147484e+09                      venezuela related designation
# 9      31  2.147484e+09  muchas ganas escribirte decirte extraño debo h...
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          1
# 8          0
# 9          1

# %% [markdown]
# **Lemmatización**

# %%
import spacy
from spacy.lang.es import Spanish
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Cargar modelo de spaCy
nlp = spacy.load("es_core_news_sm")

# Cargar stopwords en español
stopwords_es = set(stopwords.words('spanish'))

# Inicializar stemmer de NLTK
stemmer = PorterStemmer()

# %%
import pandas as pd
import spacy
from spacy.lang.es import Spanish
from nltk.corpus import stopwords


# Cargar modelo de spaCy
nlp = spacy.load("es_core_news_sm")

# Cargar stopwords en español
stopwords_es = set(stopwords.words('spanish'))
def extractTerms(text):
    if isinstance(text, str):
        # Tokenización y lematización con spaCy
        doc = nlp(text)
        lemmatized_terms = [token.lemma_ for token in doc if token.text.lower() not in stopwords_es]

        return lemmatized_terms
    else:
        return []  # Devolver una lista vacía si el texto no es una cadena de texto

# Ejemplo de uso
texto_ejemplo = "Me gustan los gatos están saltando sobre las vallas"
terminos_extraidos = extractTerms(texto_ejemplo)
print(terminos_extraidos)
# Out:
# ['gustar', 'gato', 'saltar', 'valla']

# %%
data_train['TWEET_TEXT'] = data_train.TWEET_TEXT.apply(lambda x : extractTerms(x))

# %%
data_train['TWEET_TEXT']
# Out:
# 0         [juliiakd, mayoría, piba, gustar, tener, piern...
# 1                              [empezar, sintiéndote, solo]
# 2            [mier, lindo, escrachan, instagram, magnifico]
# 3                                                        []
# 4         [seguir, cumple, deber, pronto, vestido, novia...
#                                 ...
# 263945                    [tocar, gato, madrugador, camado]
# 263946    [lamatanza, presidente, centroindustrialpanade...
# 263947                   [relación, toxico, conmigo, mismo]
# 263948                                 [sonar, convincente]
# 263949    [hora, dormir, decir, llorar, cuarto, oficials...
# Name: TWEET_TEXT, Length: 263841, dtype: object

# %%
data_train.head(10)
# Out:
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  ['juliiakd', 'mayoría', 'piba', 'gustar', 'ten...
# 1       6  2.147484e+09                 ['empezar', 'sintiéndote', 'solo']
# 2     279  2.147484e+09  ['mier', 'lindo', 'escrachan', 'instagram', 'm...
# 3     518  2.147484e+09                                                 []
# 4     301  2.147484e+09  ['seguir', 'cumple', 'deber', 'pronto', 'vesti...
# 5     177  2.147484e+09         ['sebbasrp', 'dejar', 'dormir', 'prójimo']
# 6      45  2.147484e+09     ['crookedgirlx', 'querer', 'vivir', 'cansado']
# 7      29  2.147484e+09  ['esunbreakable', 'poquito', 'vergüenza', 'alg...
# 8     388  2.147484e+09            ['venezuela', 'related', 'designation']
# 9      31  2.147484e+09  ['mucho', 'gana', 'escribirtar', 'decirte', 'e...
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          1
# 8          0
# 9          1

# %%
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x) # Combinar los elementos de la lista en una sola cadena separados por espacios
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].astype(str)
data_train
# Out:
#        USER_ID      TWEET_ID  \
# 0           87  2.147484e+09
# 1            6  2.147484e+09
# 2          279  2.147484e+09
# 3          518  2.147484e+09
# 4          301  2.147484e+09
# ...        ...           ...
# 263945      53  2.147484e+09
# 263946     246  2.147484e+09
# 263947      82  2.147484e+09
# 263948     355  2.147484e+09
# 263949      13  2.147484e+09
#
#                                                TWEET_TEXT  trastorno
# 0         juliiakd  por qué   mayoría  las pibas  les ...          1
# 1                             empezar   sintiéndote solo           1
# 2        mirá que lindo como  escrachan  instagram  ma...          0
# 3                                                                  0
# 4        sigue con   cumple  deber  muy pronto vestida...          0
# ...                                                   ...        ...
# 263945           por que  toco  gato madrugador   camada           1
# 263946   lamatanza     presidente del  centroindustria...          0
# 263947           tengo una relación toxica conmigo mismo           1
# 263948                                 suena convincente           0
# 263949  hora  dormir              dijo llorando   cuar...          1
#
# [263950 rows x 4 columns]

# %% [markdown]
# # **Usar LIWC para extraer las caracteristicas del texto**

# %%
corpus = []
words = []

for i in range(0,len(data_train)):
    review = re.sub('[^a-zA-Z0-9]',' ',data_train['TWEET_TEXT'][i])
    review = review.lower()
    review = review.split()
    review = list(category for token in review for category in parse(token))
    statements = ' '.join(review)
    corpus.append(statements)
    words.append(review)

# %% [markdown]
# # **Metodo TfidfVectorizer**

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# vectorizer=TfidfVectorizer(max_features=5000)
# X_fit=vectorizer.fit(corpus)
# X_transformed=X_fit.transform(corpus)
# features = vectorizer.get_feature_names_out()
# df_count = pd.DataFrame(X_transformed.toarray(),columns = features)
# df_count

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect  = TfidfVectorizer()

# Aplicar el TfidfVectorizer a la columna 'TWEET_TEXT' en data_train y obtener la matriz TF-IDF
tfidf_train  = tfidf_vect.fit_transform(corpus)
# Imprimir el tamaño del vocabulario construido por TfidfVectorizer
print("El tamaño del vocabulario es: ", len(tfidf_vect.vocabulary_))

X = tfidf_train # Matriz TF-IDF
y = data_train['trastorno'].values # Etiquetas de trastorno de la columna 'trastorno'

features = tfidf_vect.get_feature_names_out()

df_count = pd.DataFrame(tfidf_train.toarray(),columns = features)
df_count
# Out:
# El tamaño del vocabulario es:  73
#           adverb     afect    amigos  ansiedad  articulo  asentir    biolog  \
# 0       0.000000  0.106594  0.000000       0.0  0.144806      0.0  0.000000
# 1       0.000000  0.508752  0.000000       0.0  0.000000      0.0  0.000000
# 2       0.282760  0.000000  0.000000       0.0  0.000000      0.0  0.289008
# 3       0.000000  0.000000  0.000000       0.0  0.000000      0.0  0.000000
# 4       0.355186  0.000000  0.358648       0.0  0.000000      0.0  0.000000
# ...          ...       ...       ...       ...       ...      ...       ...
# 263945  0.000000  0.000000  0.000000       0.0  0.000000      0.0  0.000000
# 263946  0.000000  0.000000  0.000000       0.0  0.538494      0.0  0.000000
# 263947  0.000000  0.000000  0.000000       0.0  0.217865      0.0  0.000000
# 263948  0.000000  0.000000  0.000000       0.0  0.000000      0.0  0.000000
# 263949  0.000000  0.138082  0.000000       0.0  0.000000      0.0  0.183505
#
#         causa   certeza   conjunc  ...  verbaux  verbellos  verbnos    verbos  \
# 0         0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.175655
# 1         0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.000000
# 2         0.0  0.000000  0.297764  ...      0.0        0.0      0.0  0.179184
# 3         0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.000000
# 4         0.0  0.241995  0.000000  ...      0.0        0.0      0.0  0.112540
# ...       ...       ...       ...  ...      ...        ...      ...       ...
# 263945    0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.229358
# 263946    0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.000000
# 263947    0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.132139
# 263948    0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.000000
# 263949    0.0  0.000000  0.000000  ...      0.0        0.0      0.0  0.341316
#
#         verbosel  verbtu  verbvos    verbyo   vosutds        yo
# 0       0.190148     0.0      0.0  0.000000  0.274481  0.000000
# 1       0.000000     0.0      0.0  0.000000  0.000000  0.000000
# 2       0.000000     0.0      0.0  0.000000  0.000000  0.000000
# 3       0.000000     0.0      0.0  0.000000  0.000000  0.000000
# 4       0.000000     0.0      0.0  0.000000  0.000000  0.000000
# ...          ...     ...      ...       ...       ...       ...
# 263945  0.000000     0.0      0.0  0.000000  0.000000  0.000000
# 263946  0.000000     0.0      0.0  0.000000  0.000000  0.000000
# 263947  0.000000     0.0      0.0  0.256096  0.000000  0.431874
# 263948  0.000000     0.0      0.0  0.000000  0.000000  0.000000
# 263949  0.246319     0.0      0.0  0.000000  0.000000  0.000000
#
# [263950 rows x 73 columns]

# %%
print(X.shape)
print(y.shape)
# Out:
# (263950, 73)
# (263950,)

# %% [markdown]
# # **Dividir los datos de entrenamiento y prueba**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import load_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
# Convertir la matriz TF-IDF a una matriz densa de Numpy
X = X.toarray()

# Dividir los datos en conjuntos de entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)
# Verificar las dimensiones de los conjuntos de entrenamiento y validación
print("Dimensiones de X_train:", X_train.shape)
print("Dimensiones de X_val:", X_val.shape)
print("Dimensiones de y_train:", y_train.shape)
print("Dimensiones de y_val:", y_val.shape)
# Out:
# Dimensiones de X_train: (197962, 73)
# Dimensiones de X_val: (65988, 73)
# Dimensiones de y_train: (197962,)
# Dimensiones de y_val: (65988,)

# %% [markdown]
# #**Aprendizaje del modelo: Red Neuronal simple**

# %%
# Crear una red neuronal secuencial
model_R = Sequential()

# Agregar una capa de entrada con el número de características (vocabulario) en tu matriz TF-IDF
model_R.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model_R.add(Dropout(0.1))  # Dropout para regularización

# Agregar una capa oculta
model_R.add(Dense(64, activation='relu'))
model_R.add(Dropout(0.1))  # Dropout para regularización

# Agregar una capa de salida con una neurona y función de activación sigmoide para clasificación binaria
model_R.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model_R.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo en los datos de entrenamiento
history = model_R.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))

# Evaluar el modelo en el conjunto de validación
y_val_pred = (model_R.predict(X_val) > 0.5).astype(int)

# Calcular métricas de evaluación en el conjunto de validación
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred)
recall = recall_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred)

# Calcular métricas de evaluación en el conjunto de entrenamiento
y_train_pred = (model_R.predict(X_train) > 0.5).astype(int)

accuracy_train = accuracy_score(y_train, y_train_pred)
precision_train = precision_score(y_train, y_train_pred)
recall_train = recall_score(y_train, y_train_pred)
f1_train = f1_score(y_train, y_train_pred)
# Guardar el modelo entrenado
model_R.save('/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LIWC/TFIDF/parametros/modelo_entrenado_TFIDF_RN.h5')

# Cargar el modelo entrenado
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LIWC/TFIDF/parametros/modelo_entrenado_TFIDF_RN.h5')
# Out:
# Epoch 1/100
# 6187/6187 [==============================] - 23s 4ms/step - loss: 0.5967 - accuracy: 0.6724 - val_loss: 0.5875 - val_accuracy: 0.6797
# Epoch 2/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5805 - accuracy: 0.6866 - val_loss: 0.5810 - val_accuracy: 0.6856
# Epoch 3/100
# 6187/6187 [==============================] - 23s 4ms/step - loss: 0.5744 - accuracy: 0.6913 - val_loss: 0.5768 - val_accuracy: 0.6850
# Epoch 4/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5706 - accuracy: 0.6930 - val_loss: 0.5770 - val_accuracy: 0.6879
# Epoch 5/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5676 - accuracy: 0.6953 - val_loss: 0.5757 - val_accuracy: 0.6890
# Epoch 6/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5646 - accuracy: 0.6983 - val_loss: 0.5749 - val_accuracy: 0.6899
# Epoch 7/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5625 - accuracy: 0.6982 - val_loss: 0.5759 - val_accuracy: 0.6913
# Epoch 8/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5605 - accuracy: 0.7002 - val_loss: 0.5719 - val_accuracy: 0.6918
# Epoch 9/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5584 - accuracy: 0.7022 - val_loss: 0.5734 - val_accuracy: 0.6918
# Epoch 10/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5570 - accuracy: 0.7032 - val_loss: 0.5727 - val_accuracy: 0.6930
# Epoch 11/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5548 - accuracy: 0.7039 - val_loss: 0.5728 - val_accuracy: 0.6918
# Epoch 12/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5540 - accuracy: 0.7042 - val_loss: 0.5719 - val_accuracy: 0.6918
# Epoch 13/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5518 - accuracy: 0.7069 - val_loss: 0.5735 - val_accuracy: 0.6924
# Epoch 14/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5511 - accuracy: 0.7072 - val_loss: 0.5723 - val_accuracy: 0.6918
# Epoch 15/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5501 - accuracy: 0.7069 - val_loss: 0.5727 - val_accuracy: 0.6911
# Epoch 16/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5487 - accuracy: 0.7082 - val_loss: 0.5729 - val_accuracy: 0.6921
# Epoch 17/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5475 - accuracy: 0.7098 - val_loss: 0.5737 - val_accuracy: 0.6905
# Epoch 18/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5457 - accuracy: 0.7107 - val_loss: 0.5743 - val_accuracy: 0.6925
# Epoch 19/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5450 - accuracy: 0.7112 - val_loss: 0.5752 - val_accuracy: 0.6905
# Epoch 20/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5440 - accuracy: 0.7125 - val_loss: 0.5750 - val_accuracy: 0.6903
# Epoch 21/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5432 - accuracy: 0.7129 - val_loss: 0.5760 - val_accuracy: 0.6921
# Epoch 22/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5416 - accuracy: 0.7134 - val_loss: 0.5742 - val_accuracy: 0.6917
# Epoch 23/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5414 - accuracy: 0.7138 - val_loss: 0.5750 - val_accuracy: 0.6923
# Epoch 24/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5406 - accuracy: 0.7145 - val_loss: 0.5754 - val_accuracy: 0.6924
# Epoch 25/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5402 - accuracy: 0.7143 - val_loss: 0.5743 - val_accuracy: 0.6925
# Epoch 26/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5388 - accuracy: 0.7158 - val_loss: 0.5776 - val_accuracy: 0.6905
# Epoch 27/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5380 - accuracy: 0.7159 - val_loss: 0.5755 - val_accuracy: 0.6917
# Epoch 28/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5377 - accuracy: 0.7166 - val_loss: 0.5762 - val_accuracy: 0.6908
# Epoch 29/100
# 6187/6187 [==============================] - 18s 3ms/step - loss: 0.5372 - accuracy: 0.7172 - val_loss: 0.5759 - val_accuracy: 0.6926
# Epoch 30/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5366 - accuracy: 0.7174 - val_loss: 0.5763 - val_accuracy: 0.6918
# Epoch 31/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5357 - accuracy: 0.7174 - val_loss: 0.5762 - val_accuracy: 0.6902
# Epoch 32/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5349 - accuracy: 0.7189 - val_loss: 0.5771 - val_accuracy: 0.6914
# Epoch 33/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5345 - accuracy: 0.7185 - val_loss: 0.5774 - val_accuracy: 0.6912
# Epoch 34/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5333 - accuracy: 0.7188 - val_loss: 0.5787 - val_accuracy: 0.6901
# Epoch 35/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5333 - accuracy: 0.7189 - val_loss: 0.5776 - val_accuracy: 0.6920
# Epoch 36/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5323 - accuracy: 0.7201 - val_loss: 0.5802 - val_accuracy: 0.6896
# Epoch 37/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5323 - accuracy: 0.7205 - val_loss: 0.5790 - val_accuracy: 0.6921
# Epoch 38/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5306 - accuracy: 0.7219 - val_loss: 0.5789 - val_accuracy: 0.6912
# Epoch 39/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5312 - accuracy: 0.7201 - val_loss: 0.5795 - val_accuracy: 0.6903
# Epoch 40/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5299 - accuracy: 0.7210 - val_loss: 0.5792 - val_accuracy: 0.6907
# Epoch 41/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5303 - accuracy: 0.7199 - val_loss: 0.5803 - val_accuracy: 0.6906
# Epoch 42/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5294 - accuracy: 0.7212 - val_loss: 0.5808 - val_accuracy: 0.6902
# Epoch 43/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5288 - accuracy: 0.7227 - val_loss: 0.5789 - val_accuracy: 0.6901
# Epoch 44/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5284 - accuracy: 0.7230 - val_loss: 0.5810 - val_accuracy: 0.6889
# Epoch 45/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5281 - accuracy: 0.7228 - val_loss: 0.5799 - val_accuracy: 0.6881
# Epoch 46/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5275 - accuracy: 0.7237 - val_loss: 0.5826 - val_accuracy: 0.6897
# Epoch 47/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5271 - accuracy: 0.7236 - val_loss: 0.5823 - val_accuracy: 0.6881
# Epoch 48/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5274 - accuracy: 0.7238 - val_loss: 0.5803 - val_accuracy: 0.6893
# Epoch 49/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5260 - accuracy: 0.7239 - val_loss: 0.5815 - val_accuracy: 0.6889
# Epoch 50/100
# 6187/6187 [==============================] - 23s 4ms/step - loss: 0.5258 - accuracy: 0.7249 - val_loss: 0.5800 - val_accuracy: 0.6888
# Epoch 51/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5261 - accuracy: 0.7246 - val_loss: 0.5833 - val_accuracy: 0.6882
# Epoch 52/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5247 - accuracy: 0.7257 - val_loss: 0.5834 - val_accuracy: 0.6902
# Epoch 53/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5248 - accuracy: 0.7253 - val_loss: 0.5836 - val_accuracy: 0.6882
# Epoch 54/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5238 - accuracy: 0.7261 - val_loss: 0.5838 - val_accuracy: 0.6881
# Epoch 55/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5237 - accuracy: 0.7262 - val_loss: 0.5825 - val_accuracy: 0.6880
# Epoch 56/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5234 - accuracy: 0.7261 - val_loss: 0.5827 - val_accuracy: 0.6890
# Epoch 57/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5232 - accuracy: 0.7263 - val_loss: 0.5826 - val_accuracy: 0.6899
# Epoch 58/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5235 - accuracy: 0.7264 - val_loss: 0.5835 - val_accuracy: 0.6885
# Epoch 59/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5224 - accuracy: 0.7262 - val_loss: 0.5830 - val_accuracy: 0.6895
# Epoch 60/100
# 6187/6187 [==============================] - 18s 3ms/step - loss: 0.5226 - accuracy: 0.7276 - val_loss: 0.5836 - val_accuracy: 0.6902
# Epoch 61/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5224 - accuracy: 0.7267 - val_loss: 0.5881 - val_accuracy: 0.6888
# Epoch 62/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5220 - accuracy: 0.7264 - val_loss: 0.5830 - val_accuracy: 0.6892
# Epoch 63/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5218 - accuracy: 0.7275 - val_loss: 0.5838 - val_accuracy: 0.6887
# Epoch 64/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5211 - accuracy: 0.7281 - val_loss: 0.5845 - val_accuracy: 0.6883
# Epoch 65/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5202 - accuracy: 0.7281 - val_loss: 0.5856 - val_accuracy: 0.6890
# Epoch 66/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5209 - accuracy: 0.7275 - val_loss: 0.5837 - val_accuracy: 0.6891
# Epoch 67/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5199 - accuracy: 0.7280 - val_loss: 0.5858 - val_accuracy: 0.6890
# Epoch 68/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5198 - accuracy: 0.7284 - val_loss: 0.5864 - val_accuracy: 0.6888
# Epoch 69/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5197 - accuracy: 0.7283 - val_loss: 0.5877 - val_accuracy: 0.6882
# Epoch 70/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5186 - accuracy: 0.7299 - val_loss: 0.5885 - val_accuracy: 0.6891
# Epoch 71/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5202 - accuracy: 0.7283 - val_loss: 0.5861 - val_accuracy: 0.6876
# Epoch 72/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5180 - accuracy: 0.7302 - val_loss: 0.5851 - val_accuracy: 0.6889
# Epoch 73/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5179 - accuracy: 0.7296 - val_loss: 0.5866 - val_accuracy: 0.6871
# Epoch 74/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5179 - accuracy: 0.7295 - val_loss: 0.5864 - val_accuracy: 0.6873
# Epoch 75/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5179 - accuracy: 0.7293 - val_loss: 0.5873 - val_accuracy: 0.6874
# Epoch 76/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5184 - accuracy: 0.7288 - val_loss: 0.5841 - val_accuracy: 0.6876
# Epoch 77/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5180 - accuracy: 0.7292 - val_loss: 0.5842 - val_accuracy: 0.6874
# Epoch 78/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5172 - accuracy: 0.7287 - val_loss: 0.5857 - val_accuracy: 0.6896
# Epoch 79/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5169 - accuracy: 0.7305 - val_loss: 0.5871 - val_accuracy: 0.6877
# Epoch 80/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5165 - accuracy: 0.7301 - val_loss: 0.5869 - val_accuracy: 0.6876
# Epoch 81/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5173 - accuracy: 0.7301 - val_loss: 0.5871 - val_accuracy: 0.6886
# Epoch 82/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5161 - accuracy: 0.7306 - val_loss: 0.5864 - val_accuracy: 0.6882
# Epoch 83/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5158 - accuracy: 0.7311 - val_loss: 0.5877 - val_accuracy: 0.6897
# Epoch 84/100
# 6187/6187 [==============================] - 20s 3ms/step - loss: 0.5155 - accuracy: 0.7314 - val_loss: 0.5871 - val_accuracy: 0.6873
# Epoch 85/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5160 - accuracy: 0.7313 - val_loss: 0.5862 - val_accuracy: 0.6861
# Epoch 86/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5153 - accuracy: 0.7308 - val_loss: 0.5893 - val_accuracy: 0.6881
# Epoch 87/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5151 - accuracy: 0.7309 - val_loss: 0.5881 - val_accuracy: 0.6868
# Epoch 88/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5153 - accuracy: 0.7317 - val_loss: 0.5897 - val_accuracy: 0.6879
# Epoch 89/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5147 - accuracy: 0.7315 - val_loss: 0.5904 - val_accuracy: 0.6876
# Epoch 90/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5149 - accuracy: 0.7310 - val_loss: 0.5882 - val_accuracy: 0.6878
# Epoch 91/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5147 - accuracy: 0.7324 - val_loss: 0.5882 - val_accuracy: 0.6883
# Epoch 92/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5145 - accuracy: 0.7322 - val_loss: 0.5881 - val_accuracy: 0.6881
# Epoch 93/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5142 - accuracy: 0.7318 - val_loss: 0.5884 - val_accuracy: 0.6864
# Epoch 94/100
# 6187/6187 [==============================] - 21s 3ms/step - loss: 0.5137 - accuracy: 0.7326 - val_loss: 0.5886 - val_accuracy: 0.6874
# Epoch 95/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5143 - accuracy: 0.7319 - val_loss: 0.5882 - val_accuracy: 0.6877
# Epoch 96/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5134 - accuracy: 0.7327 - val_loss: 0.5901 - val_accuracy: 0.6883
# Epoch 97/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5132 - accuracy: 0.7325 - val_loss: 0.5887 - val_accuracy: 0.6871
# Epoch 98/100
# 6187/6187 [==============================] - 22s 4ms/step - loss: 0.5120 - accuracy: 0.7329 - val_loss: 0.5904 - val_accuracy: 0.6880
# Epoch 99/100
# 6187/6187 [==============================] - 22s 3ms/step - loss: 0.5135 - accuracy: 0.7328 - val_loss: 0.5899 - val_accuracy: 0.6887
# Epoch 100/100
# 6187/6187 [==============================] - 19s 3ms/step - loss: 0.5139 - accuracy: 0.7327 - val_loss: 0.5902 - val_accuracy: 0.6862
# 2063/2063 [==============================] - 3s 1ms/step
# 6187/6187 [==============================] - 10s 2ms/step

# %%
# Imprimir métricas de entrenamiento
print("\nMétricas en el conjunto de entrenamiento:")
print(f"Exactitud (entrenamiento): {round(accuracy_train, 2) * 100}%")
print(f"Precisión (entrenamiento): {round(precision_train, 2) * 100}%")
print(f"Recall (entrenamiento): {round(recall_train, 2) * 100}%")
print(f"F1-score (entrenamiento): {round(f1_train, 2) * 100}%")
print('-------------------------------------------------------------------------')
# Imprimir métricas de evaluación
print(f"Exactitud en el conjunto de validación: {round(accuracy, 2) * 100}%")
print(f"Precisión en el conjunto de validación: {round(precision, 2) * 100}%")
print(f"Recall en el conjunto de validación: {round(recall, 2) * 100}%")
print(f"F1-score en el conjunto de validación: {round(f1, 2) * 100}%")
# Out:
# Métricas en el conjunto de entrenamiento:
# Exactitud (entrenamiento): 75.0%
# Precisión (entrenamiento): 73.0%
# Recall (entrenamiento): 81.0%
# F1-score (entrenamiento): 77.0%
# -------------------------------------------------------------------------
# Exactitud en el conjunto de validación: 69.0%
# Precisión en el conjunto de validación: 66.0%
# Recall en el conjunto de validación: 75.0%
# F1-score en el conjunto de validación: 70.0%

# %%
from sklearn.metrics import confusion_matrix

y_pred = model_R.predict(X_val)

# Obtiene la matriz de confusión. Las filas corresponden a las clases reales,
umbral = 0.5  # Puedes ajustar este umbral según tus necesidades
y_pred_binario = (y_pred > umbral).astype(int)

# Calcular la matriz de confusión con las etiquetas binarias
cm = confusion_matrix(y_val, y_pred_binario)
prop_real = np.sum(y_val)/len(y_val)
prop_etiqutados = (cm[0,1]+cm[1,1])/len(y_val)

print("Matriz de confusión: \n\n", cm, "\n")
print('Proporción de comentarios positivos: %.2f'% prop_real)
print('Proporción de comentarios positivos etiquetados: %.2f'% prop_etiqutados)
# Out:
# 2063/2063 [==============================] - 3s 2ms/step
# Matriz de confusión:
#
#  [[20725 12381]
#  [ 8325 24557]]
#
# Proporción de comentarios positivos: 0.50
# Proporción de comentarios positivos etiquetados: 0.56

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una figura para la matriz de confusión
plt.figure(figsize=(8, 6))

# Crear una matriz de confusión usando el heatmap de Seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Control', 'Depresión'], yticklabels=['Control', 'Depresión'])

# Etiquetas y título
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Entrenamiento con validación cruzada k=10

# %%
# Crear una red neuronal secuencial
model = Sequential()

# Agregar una capa de entrada con el número de características (vocabulario) en tu matriz TF-IDF
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.1))  # Dropout para regularización

# Agregar una capa oculta
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))  # Dropout para regularización

# Agregar una capa de salida con una neurona y función de activación sigmoide para clasificación binaria
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Definir la estrategia de validación cruzada (k=10)
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Listas para almacenar métricas de entrenamiento y validación
train_accuracy_scores = []
train_precision_scores = []
train_recall_scores = []
train_f1_scores = []

# Realizar la validación cruzada
for train_index, val_index in cv.split(X_train, y_train):
    X_train_index, X_val_index = X_train[train_index], X_train[val_index]
    y_train_index, y_val_index = y[train_index], y[val_index]

    # Entrenar el modelo en los datos de entrenamiento
    model.fit(X_train_index, y_train_index, epochs=10, batch_size=32, verbose=0)

    # Evaluar el modelo en el conjunto de entrenamiento
    y_train_pred = (model.predict(X_train_index) > 0.5).astype(int)

    # Calcular métricas de entrenamiento y agregarlas a las listas
    train_accuracy_scores.append(accuracy_score(y_train_index, y_train_pred))
    train_precision_scores.append(precision_score(y_train_index, y_train_pred))
    train_recall_scores.append(recall_score(y_train_index, y_train_pred))
    train_f1_scores.append(f1_score(y_train_index, y_train_pred))

# Calcular las métricas promediadas en entrenamiento
train_accuracy_mean = np.mean(train_accuracy_scores)
train_precision_mean = np.mean(train_precision_scores)
train_recall_mean = np.mean(train_recall_scores)
train_f1_mean = np.mean(train_f1_scores)

# Imprimir las métricas en entrenamiento
print("Entrenamiento - Accuracy: {:.2f}%".format(100 * train_accuracy_mean))
print("Entrenamiento - Precision: {:.2f}%".format(100 * train_precision_mean))
print("Entrenamiento - Recall: {:.2f}%".format(100 * train_recall_mean))
print("Entrenamiento - F1 Score: {:.2f}%".format(100 * train_f1_mean))

# Listas para almacenar métricas de validación
val_accuracy_scores = []
val_precision_scores = []
val_recall_scores = []
val_f1_scores = []

# Realizar la validación cruzada
for train_index, val_index in cv.split(X_train, y_train):
    X_train_index, X_val_index = X_train[train_index], X_train[val_index]
    y_train_index, y_val_index = y_train[train_index], y_train[val_index]

    # Entrenar el modelo en los datos de entrenamiento
    model.fit(X_train_index, y_train_index, epochs=10, batch_size=32, verbose=0)

    # Evaluar el modelo en el conjunto de validación
    y_val_pred = (model.predict(X_val_index) > 0.5).astype(int)

    # Calcular métricas de validación y agregarlas a las listas
    val_accuracy_scores.append(accuracy_score(y_val_index, y_val_pred))
    val_precision_scores.append(precision_score(y_val_index, y_val_pred))
    val_recall_scores.append(recall_score(y_val_index, y_val_pred))
    val_f1_scores.append(f1_score(y_val_index, y_val_pred))

# Calcular las métricas promediadas en validación
val_accuracy_mean = np.mean(val_accuracy_scores)
val_precision_mean = np.mean(val_precision_scores)
val_recall_mean = np.mean(val_recall_scores)
val_f1_mean = np.mean(val_f1_scores)

# Imprimir las métricas en validación
print("Validación - Accuracy: {:.2f}%".format(100 * val_accuracy_mean))
print("Validación - Precision: {:.2f}%".format(100 * val_precision_mean))
print("Validación - Recall: {:.2f}%".format(100 * val_recall_mean))
print("Validación - F1 Score: {:.2f}%".format(100 * val_f1_mean))

# Guardar el modelo entrenado
model_R.save('/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LIWC/TFIDF/parametros/modelo_entrenado_TFIDF_RN(K=10).h5')

# Cargar el modelo entrenado
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LIWC/TFIDF/parametros/modelo_entrenado_TFIDF_RN(K=10).h5')

# %%
# Imprimir las métricas en entrenamiento
print("Entrenamiento - Accuracy: {:.2f}%".format(100 * train_accuracy_mean))
print("Entrenamiento - Precision: {:.2f}%".format(100 * train_precision_mean))
print("Entrenamiento - Recall: {:.2f}%".format(100 * train_recall_mean))
print("Entrenamiento - F1 Score: {:.2f}%".format(100 * train_f1_mean))
print('-----------------------------------------------------------------------')
# Imprimir las métricas en validación
print("Validación - Accuracy: {:.2f}%".format(100 * val_accuracy_mean))
print("Validación - Precision: {:.2f}%".format(100 * val_precision_mean))
print("Validación - Recall: {:.2f}%".format(100 * val_recall_mean))
print("Validación - F1 Score: {:.2f}%".format(100 * val_f1_mean))
# Out:
# Entrenamiento - Accuracy: 59.34%
# Entrenamiento - Precision: 57.37%
# Entrenamiento - Recall: 73.50%
# Entrenamiento - F1 Score: 64.41%
# -----------------------------------------------------------------------
# Validación - Accuracy: 70.76%
# Validación - Precision: 68.19%
# Validación - Recall: 78.04%
# Validación - F1 Score: 72.77%

# %%
from sklearn.metrics import confusion_matrix
with tf.device('/device:CPU:0'):
  y_pred = model.predict(X_val_index)

# Obtiene la matriz de confusión. Las filas corresponden a las clases reales,
umbral = 0.5  # Puedes ajustar este umbral según tus necesidades
y_pred_binario = (y_pred > umbral).astype(int)

# Calcular la matriz de confusión con las etiquetas binarias
cm = confusion_matrix(y_val_index, y_pred_binario)
prop_real = np.sum(y_val_index)/len(y_val_index)
prop_etiqutados = (cm[0,1]+cm[1,1])/len(y_val_index)

print("Matriz de confusión: \n\n", cm, "\n")
print('Proporción de comentarios positivos: %.2f'% prop_real)
print('Proporción de comentarios positivos etiquetados: %.2f'% prop_etiqutados)
# Out:
# 619/619 [==============================] - 1s 1ms/step
# Matriz de confusión:
#
#  [[6467 3409]
#  [2098 7822]]
#
# Proporción de comentarios positivos: 0.50
# Proporción de comentarios positivos etiquetados: 0.57

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una figura para la matriz de confusión
plt.figure(figsize=(8, 6))

# Crear una matriz de confusión usando el heatmap de Seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Control', 'Depresión'], yticklabels=['Control', 'Depresión'])

# Etiquetas y título
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión')

# Mostrar la gráfica
plt.show()

# %%
import joblib
import os
# Directorio para guardar modelos entrenados
model_dir = '/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LIWC/TFIDF/parametros'
model_filename = 'TWEETS_depresivos (RN-CV=10).pkl'
model_path_p = os.path.join(model_dir, model_filename)

# Guardar el modelo entrenado
joblib.dump(model, model_path_p)
# Out:
# ['/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LIWC/TFIDF/parametros/TWEETS_depresivos (RN-CV=10).pkl']
