# %%
# !pip install nltk
# !pip install spacy
# !python -m spacy download es_core_news_sm
# !pip install -U imbalanced-learn
# !pip install pyspellchecker

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Oculta warnings
import warnings
warnings.simplefilter('ignore')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # CARGAR DATOS
# **DATOS DE ENTRENAMIENTO**
#
# la columna de trastornos indica si el TWEET es de una persona con depresión o es de control.
#
#
# **control**:     0
#
# **depresión**:   1

# %%
ruta_archivo_entrenamiento = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs depresión)/train.csv'
data_train = pd.read_csv(ruta_archivo_entrenamiento, sep=',')
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263950 entries, 0 to 263949
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     263950 non-null  object
#  1   TWEET_ID    263920 non-null  float64
#  2   TWEET_TEXT  263841 non-null  object
#  3   trastorno   263950 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.1+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  RT @Julii_AKD: por qué a la mayoría de las pib...
# 1       6  2.147484e+09                  Empezar un 2017 sintiéndote solo.
# 2     279  2.147484e+09  Ah mirá que lindo como me escrachan en Instagr...
# 3     518  2.147484e+09                            https://t.co/hC3rULMb1P
# 4     301  2.147484e+09  Tu sigue con él, cumple tu deber, muy pronto v...
# 5     177  2.147484e+09                  @Sebbasrp deje dormir al prójimo.
# 6      45  2.147484e+09  RT @Crookedgirlx: no quiero vivir más, estoy c...
# 7      29  2.147484e+09  RT @Esunbreakable: Me da un poquito de vergüen...
# 8     388  2.147484e+09  Venezuela-related Designation https://t.co/IOZ...
# 9      31  2.147484e+09  Tengo muchas ganas de escribirte para decirte ...
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          1
# 8          0
# 9          1

# %% [markdown]
# #DATOS DE PRUEBA

# %%
#num_docs = 50000

# %%
ruta_archivo_prueba = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs depresión)/train.csv'
data_train = pd.read_csv(ruta_archivo_prueba, sep=',')
#data = pd.read_csv(ruta_archivo_entrenamiento, sep=',')
#data_train = data.iloc[:num_docs, :]
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263950 entries, 0 to 263949
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     263950 non-null  object
#  1   TWEET_ID    263920 non-null  float64
#  2   TWEET_TEXT  263841 non-null  object
#  3   trastorno   263950 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.1+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  RT @Julii_AKD: por qué a la mayoría de las pib...
# 1       6  2.147484e+09                  Empezar un 2017 sintiéndote solo.
# 2     279  2.147484e+09  Ah mirá que lindo como me escrachan en Instagr...
# 3     518  2.147484e+09                            https://t.co/hC3rULMb1P
# 4     301  2.147484e+09  Tu sigue con él, cumple tu deber, muy pronto v...
# 5     177  2.147484e+09                  @Sebbasrp deje dormir al prójimo.
# 6      45  2.147484e+09  RT @Crookedgirlx: no quiero vivir más, estoy c...
# 7      29  2.147484e+09  RT @Esunbreakable: Me da un poquito de vergüen...
# 8     388  2.147484e+09  Venezuela-related Designation https://t.co/IOZ...
# 9      31  2.147484e+09  Tengo muchas ganas de escribirte para decirte ...
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          1
# 8          0
# 9          1

# %% [markdown]
# # DATOS DE PRUEBA (TEST)

# %%
num_docs_test = 50000

# %%
ruta_archivo_prueba = '/content/drive/MyDrive/Experimentación Python Tesis /entrenamiento y prueba (control vs depresión)/test.csv'
data_test = pd.read_csv(ruta_archivo_prueba, lineterminator='\n')
#data_t = pd.read_csv(ruta_archivo_prueba, lineterminator='\n')
#data_test =data_t.iloc[:num_docs_test, :]
data_test.info()
data_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113075 entries, 0 to 113074
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     113075 non-null  int64
#  1   TWEET_ID    113075 non-null  int64
#  2   TWEET_TEXT  113075 non-null  object
#  3   trastorno   113075 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 3.5+ MB
#    USER_ID    TWEET_ID                                         TWEET_TEXT  \
# 0       30  2147483647  RT @Unicornio_Azul5: ¿Está mal desear estar mu...
# 1      508  2147483647  RT @tachame_ladoble: Esta noche!! Volvemos a V...
# 2      279  2147483647  RT @PsychdelicPics: Art by I Love Doodle https...
# 3       12  2147483647                   Hoy no he pasado de las 700kcal.
# 4      277  2147483647  RT @NetSportAcademy: Elisa Luque se proclama c...
#
#    trastorno
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0

# %% [markdown]
# #Preprocesamiento de los datos

# %%
import nltk
nltk.download('stopwords')  #Solamente se ha de descargar la primera vez.
stopwords_en = nltk.corpus.stopwords.words('spanish')   # Extrae las stopwords en español
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# *Eliminar etiquetas HTML*

# %%
import re

def removeHTML(text):
    if isinstance(text, str):  # Verificar si es de tipo string
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, '', text)
        return cleantext
    else:
        return text  # Devolver el valor original si no es de tipo string

# %% [markdown]
# *Limpieza del texto*

# %%
import re
import string

def clean(text):
    if isinstance(text, str):  # Verificar si es de tipo string
        # Eliminar hashtags
        text = re.sub(r'#\w+', '', text)

        # Eliminar URLs o enlaces
        text = re.sub(r'(https?://)?[a-zA-Z0-9]+\.[a-zA-Z0-9]+\S*', '', text)

        # Eliminar nombres de usuarios de Twitter
        text = re.sub(r'@\w+', '', text)

        # Eliminar Nombres propios
        text = re.sub(r'\b[A-Z][a-z]+\b', '', text)

        # Eliminar todos los caracteres especiales
        text = re.sub(r'[^\w\s]+', '', text)

        # Eliminar prefijos y números
        text = re.sub(r'\b\w{1,2}\b|\d+', '', text)

        # Eliminar palabras específicas
        specific_words = ['retweet', 'retweets', 'hashtag', 'trending', 'mención', 'enlace', 'emoji', 'timeline', 'interacciones',
                          'tuit', 'seguidores', 'notificaciones', 'seguir', 'favorito', 'perfil', 'tendencia', 'influencer',
                          'compartir', 'actualización', 'explorar', 'seguir', 'comunidad', 'contenido', 'popular',
                          'recomendar', 'experiencia', 'conectar', 'comentar', 'compartir', 'comunidad', 'actualización',
                          'drk', 'followers', 'stats', 'for', 'new', 'little', 'unfollower', 'unfollowers', 'today', 'shit','twitter','nombre',
                          'eric','story','great', 'short','squeeze','piggly','wiggly','hmv','even','follas','you','i','he','she',
                          'it','we','they','the','and','that','these','those','tweet','followed','follower']
        text = ' '.join([word for word in text.split() if word not in specific_words])

        # Eliminar emojis
        emojis = re.findall(r'[^\w\s,]', text)
        cleaned_emojis = [emoji for emoji in emojis if emoji not in ['@', '#', '/', '?','¿','.','…','"',':','“','!','¡','°','-',"‘",'’',
                                                                     '=',';','(',')',"'","'",'&','€','%','$','*','+','|', '”','🇦','🇷',',',
                                                                     ', ','—','«',' »','»','« ','[, ]','[,]',',',', ','',' ',' ♀',' 🏽']]
        for emoji in cleaned_emojis:
            text = text.replace(emoji, '')

        # Convertir el texto a minúsculas
        text = text.lower()

        # Eliminar signos de puntuación
        text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
        # Tokenizar el texto en palabras
        words = text.split()

        # Eliminar palabras vacías
        words = [word for word in words if word not in stopwords_es]

        # Reconstruir el texto limpio
        text = ' '.join(words)
         # Combinar las stopwords en  español
        all_stopwords = stopwords_en
        # Filtrar las stopwords del texto
        filtered_words = [word for word in words if word.lower() not in all_stopwords] #filtra las palabras vacías del texto que no están en la lista de palabras vacías

        # Unir las palabras filtradas en un solo texto
        text = ' '.join(filtered_words)

        # Devuelve el texto limpio
        return text
    else:
        return text  # Devolver el valor original si no es de tipo string

# %% [markdown]
# *corrección de palabras o tokens*

# %%
# from spellchecker import SpellChecker

# def corrector_ortografico(tokens):
#     spell = SpellChecker(language='es')
#     tokens_corregidos = [spell.correction(token) if spell.correction(token) is not None else token for token in tokens]
#     return tokens_corregidos

# def corregir_palabras_largas(tokens):
#     tokens_corregidos = []
#     for token in tokens:
#         # Corregir repeticiones de letras
#         token_corregido = re.sub(r'(.)\1+', r'\1\1', token)

#         # Corregir alargamiento de palabras
#         token_corregido = re.sub(r'(\w)\1{2,}', r'\1\1', token_corregido)

#         # Eliminar vocales repetidas más de 2 veces seguidas
#         token_corregido = re.sub(r'([aeiouáéíóú]{2,})\1+', r'\1', token_corregido, flags=re.IGNORECASE)

#         tokens_corregidos.append(token_corregido)
#     return tokens_corregidos

# %% [markdown]
# *lematizar y extraer términos*

# %%
import pandas as pd
import spacy
from spacy.lang.es import Spanish
from nltk.corpus import stopwords


# Cargar modelo de spaCy
nlp = spacy.load("es_core_news_sm")

# Cargar stopwords en español
stopwords_es = set(stopwords.words('spanish'))

def extractTerms(text):
    if isinstance(text, str):
        # Tokenización y lematización con spaCy
        doc = nlp(text)
        lemmatized_terms = [token.lemma_ for token in doc if token.text.lower() not in stopwords_es]

        return lemmatized_terms
    else:
        return []  # Devolver una lista vacía si el texto no es una cadena de texto

# Ejemplo de uso
texto_ejemplo = "Los gatos están saltando sobre las vallas"
terminos_extraidos = extractTerms(texto_ejemplo)
print(terminos_extraidos)
# Out:
# ['gato', 'saltar', 'valla']

# %% [markdown]
# # Preprocesamieto del conjunto de datos de entrenamiento

# %%
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(removeHTML)
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(clean)
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(extractTerms)
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263950 entries, 0 to 263949
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     263950 non-null  object
#  1   TWEET_ID    263920 non-null  float64
#  2   TWEET_TEXT  263950 non-null  object
#  3   trastorno   263950 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.1+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  [mayoría, piba, gustar, tener, pierna, grande,...
# 1       6  2.147484e+09                                [sintiéndote, solo]
# 2     279  2.147484e+09                [mier, lindo, escrachan, magnifico]
# 3     518  2.147484e+09                                                 []
# 4     301  2.147484e+09  [seguir, cumple, deber, pronto, vestido, novia...
# 5     177  2.147484e+09                           [dejar, dormir, prójimo]
# 6      45  2.147484e+09                           [querer, vivir, cansado]
# 7      29  2.147484e+09  [poquito, vergüenza, alguien, querer, alzar yo...
# 8     388  2.147484e+09                                          [related]
# 9      31  2.147484e+09  [mucho, gana, escribirtar, decirte, extraño, d...
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          1
# 8          0
# 9          1

# %%
# Verificar si hay elementos vacíos en la columna 'TWEET_TEXT'
empty_count = (data_train['TWEET_TEXT'].apply(len) == 0).sum()

# Imprimir el número de elementos vacíos en la columna 'TWEET_TEXT'
print("Número de elementos vacíos en la columna 'TWEET_TEXT':", empty_count)
# Out:
# Número de elementos vacíos en la columna 'TWEET_TEXT': 17995

# %%
# Filtrar filas donde 'TWEET_TEXT' no sea una lista vacía
data_train = data_train[data_train['TWEET_TEXT'].apply(len) > 0]

# Reiniciar el índice del DataFrame después de eliminar filas
data_train.reset_index(drop=True, inplace=True)

# %%
# Verificar si hay elementos vacíos en la columna 'TWEET_TEXT'
empty_count = (data_train['TWEET_TEXT'].apply(len) == 0).sum()

# Imprimir el número de elementos vacíos en la columna 'TWEET_TEXT'
print("Número de elementos vacíos en la columna 'TWEET_TEXT':", empty_count)
# Out:
# Número de elementos vacíos en la columna 'TWEET_TEXT': 0

# %%
data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x) # Combinar los elementos de la lista en una sola cadena separados por espacios
data_train.info()
data_train.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245955 entries, 0 to 245954
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   USER_ID     245955 non-null  object
#  1   TWEET_ID    245955 non-null  float64
#  2   TWEET_TEXT  245955 non-null  object
#  3   trastorno   245955 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 7.5+ MB
#   USER_ID      TWEET_ID                                         TWEET_TEXT  \
# 0      87  2.147484e+09  mayoría piba gustar tener pierna grande lindo ...
# 1       6  2.147484e+09                                   sintiéndote solo
# 2     279  2.147484e+09                     mier lindo escrachan magnifico
# 3     301  2.147484e+09  seguir cumple deber pronto vestido novia estar...
# 4     177  2.147484e+09                               dejar dormir prójimo
# 5      45  2.147484e+09                               querer vivir cansado
# 6      29  2.147484e+09  poquito vergüenza alguien querer alzar yo peso...
# 7     388  2.147484e+09                                            related
# 8      31  2.147484e+09  mucho gana escribirtar decirte extraño deber h...
# 9       2  2.147484e+09                                    desear mudar yo
#
#    trastorno
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# 5          1
# 6          1
# 7          0
# 8          1
# 9          1

# %%
#from spellchecker import SpellChecker

# def corrector_ortografico(tokens):
#     spell = SpellChecker(language='es')
#     tokens_corregidos = [spell.correction(token) if spell.correction(token) is not None else token for token in tokens]
#     return tokens_corregidos

# def corregir_palabras_largas(tokens):
#     tokens_corregidos = []
#     for token in tokens:
#         # Corregir repeticiones de letras
#         token_corregido = re.sub(r'(.)\1+', r'\1\1', token)

#         # Corregir alargamiento de palabras
#         token_corregido = re.sub(r'(\w)\1{2,}', r'\1\1', token_corregido)

#         # Eliminar vocales repetidas más de 2 veces seguidas
#         token_corregido = re.sub(r'([aeiouáéíóú]{2,})\1+', r'\1', token_corregido, flags=re.IGNORECASE)

#         tokens_corregidos.append(token_corregido)
#     return tokens_corregidos

# %%
# data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(corregir_palabras_largas)
# data_train['TWEET_TEXT'] = data_train['TWEET_TEXT'].apply(corrector_ortografico)
# data_train.info()
# data_train.head(10)

# %%
# # Especifica la ubicación y el nombre del archivo CSV donde deseas guardar los datos procesados
# csv_path = '/content/drive/MyDrive/Experimentación Python Tesis /Tweets preprocesados.csv'

# # Guarda el DataFrame en un nuevo archivo CSV
# data_train.to_csv(csv_path, index=False)

# print(f"Los datos procesados se han guardado en '{csv_path}'")

# %% [markdown]
# #Vectorización de los datos

# %%
from sklearn.feature_extraction.text import CountVectorizer
def Tokenizer(text):
    return text.split()  # Tokenizador simple: divide el texto en palabras
# Crear un transformador CountVectorizer con el tokenizer Tokenizery rango de n-gramas (1, 1)
# y un umbral de frecuencia mínimo de 200
umbral = 20
count_vect = CountVectorizer(tokenizer=Tokenizer, ngram_range=(1, 1), min_df=umbral)

# Aplicar el CountVectorizer a la columna 'TWEET_TEXT' en data_train y obtener la matriz BoW
bow_train = count_vect.fit_transform(data_train['TWEET_TEXT'].values)

# Imprimir el tamaño del vocabulario construido por CountVectorizer
print("El tamaño del vocabulario es:", len(count_vect.vocabulary_))

# Crear arrays X y y para los datos y etiquetas respectivamente
X = bow_train  # Matriz BoW
y = data_train['trastorno'].values  # Etiquetas de trastorno de la columna 'trastorno'
# Out:
# El tamaño del vocabulario es: 6087

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.decomposition import LatentDirichletAllocation as LDA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Aplicar LDA para reducir la dimensionalidad
n_topics = 10  # Define el número de tópicos (componentes)
lda = LDA(n_components=n_topics)
X_train_lda = lda.fit_transform(X_train, y_train)
X_test_lda = lda.transform(X_test)

# %%
# Crear un modelo de red neuronal secuencial
model = Sequential()

input_dim = X_train_lda.shape[1]  # Obtener la dimensión de entrada
model.add(Dense(350, activation='relu', input_dim=input_dim))
model.add(Dropout(0.1))  # Dropout para regularización

# Agregar una capa oculta
model.add(Dense(250, activation='relu'))
model.add(Dropout(0.1))  # Dropout para regularización

# Agregar una capa de salida con una neurona y función de activación sigmoide para clasificación binaria
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Utilizar EarlyStopping para detener el entrenamiento si no hay mejora
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Entrenar el modelo en los datos de entrenamiento transformados por LDA
model.fit(X_train_lda, y_train, epochs=1000, batch_size=200, verbose=1, validation_data=(X_test_lda, y_test), callbacks=[early_stopping])

# Predicciones en el conjunto de prueba
y_pred = model.predict(X_test_lda)
y_pred_binary = (y_pred > 0.5).astype(int)  # Convertir probabilidades en etiquetas binarias (0 o 1)

# Calcular la precisión, recall y puntuación F1
accuracy = accuracy_score(y_test, y_pred_binary )
precision = precision_score(y_test, y_pred_binary, average='weighted')
recall = recall_score(y_test, y_pred_binary, average='weighted')
f1 = f1_score(y_test, y_pred_binary, average='weighted')
# Out:
# Epoch 1/1000
# 861/861 [==============================] - 11s 12ms/step - loss: 0.6212 - accuracy: 0.6535 - val_loss: 0.6131 - val_accuracy: 0.6598
# Epoch 2/1000
# 861/861 [==============================] - 8s 9ms/step - loss: 0.
1000
# 861/861 [==============================] - 10s 11ms/step - loss: 0.6056 - accuracy: 0.6635 - val_loss: 0.6034 - val_accuracy: 0.6660
# Epoch 50/1000
# 861/861 [==============================] - 7s 9ms/step - loss: 0.6056 - accuracy: 0.6628 - val_loss: 0.6040 - val_accuracy: 0.6667
# Epoch 51/1000
# 861/861 [==============================] - 10s 11ms/step - loss: 0.6055 - accuracy: 0.6631 - val_loss: 0.6050 - val_accuracy: 0.6655
# Epoch 52/1000
# 861/861 [==============================] - 10s 11ms/step - loss: 0.6053 - accuracy: 0.6632 - val_loss: 0.6037 - val_accuracy: 0.6642
# Epoch 53/1000
# 861/861 [==============================] - 8s 9ms/step - loss: 0.6055 - accuracy: 0.6636 - val_loss: 0.6035 - val_accuracy: 0.6659
# Epoch 54/1000
# 861/861 [==============================] - 9s 10ms/step - loss: 0.6053 - accuracy: 0.6635 - val_loss: 0.6041 - val_accuracy: 0.6655
# Epoch 55/1000
# 861/861 [==============================] - 8s 9ms/step - loss: 0.6057 - accuracy: 0.6627 - val_loss: 0.6031 - val_accuracy: 0.6633
# Epoch 56/1000
# 861/861 [==============================] - 9s 11ms/step - loss: 0.6052 - accuracy: 0.6632 - val_loss: 0.6035 - val_accuracy: 0.6637
# Epoch 57/1000
# 861/861 [==============================] - 8s 9ms/step - loss: 0.6050 - accuracy: 0.6634 - val_loss: 0.6034 - val_accuracy: 0.6663
# 2306/2306 [==============================] - 5s 2ms/step

# %%
print(f"Exactitud: {accuracy * 100:.2f}%")
print(f"Precisión: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"Puntuación F1: {f1 * 100:.2f}%")
# Out:
# Exactitud: 66.69%
# Precisión: 66.79%
# Recall: 66.69%
# Puntuación F1: 66.61%

# %%
print(f"Exactitud: {accuracy * 100:.2f}%")
print(f"Precisión: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"Puntuación F1: {f1 * 100:.2f}%")
# Out:
# Exactitud: 66.69%
# Precisión: 66.79%
# Recall: 66.69%
# Puntuación F1: 66.61%

# %% [markdown]
# # Aprensizaje del modelo: Red neuronal
# **Validación Cruzada K=10**

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.decomposition import LatentDirichletAllocation as LDA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Inicializar listas para almacenar métricas
train_accuracy_scores = []
train_precision_scores = []
train_recall_scores = []
train_f1_scores = []

val_accuracy_scores = []
val_precision_scores = []
val_recall_scores = []
val_f1_scores = []

# Crear un objeto StratifiedKFold para dividir los datos en k-folds estratificados
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

# Dividir los datos en k-folds y realizar la validación cruzada
for train_index, val_index in skf.split(X, y):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Aplicar LDA para reducir la dimensionalidad
    n_topics = 10  # Define el número de tópicos (componentes)
    lda = LDA(n_components=n_topics)
    X_train_lda = lda.fit_transform(X_train, y_train)
    X_val_lda = lda.transform(X_val)

    # Crear un modelo de red neuronal secuencial
    model = Sequential()

    input_dim = X_train_lda.shape[1]  # Obtener la dimensión de entrada
    model.add(Dense(350, activation='relu', input_dim=input_dim))
    model.add(Dropout(0.1))  # Dropout para regularización

    # Agregar una capa oculta
    model.add(Dense(250, activation='relu'))
    model.add(Dropout(0.1))  # Dropout para regularización

    # Agregar una capa de salida con una neurona y función de activación sigmoide para clasificación binaria
    model.add(Dense(1, activation='sigmoid'))

    # Compilar el modelo
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

    # Utilizar EarlyStopping para detener el entrenamiento si no hay mejora
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Entrenar el modelo en los datos de entrenamiento transformados por LDA
    model.fit(X_train_lda, y_train, epochs=1000, batch_size=200, verbose=1, validation_data=(X_val_lda, y_val), callbacks=[early_stopping])

    # Predicciones en el conjunto de entrenamiento y validación
    y_train_pred = (model.predict(X_train_lda) > 0.5).astype(int)
    y_val_pred = (model.predict(X_val_lda) > 0.5).astype(int)

    # Calcular métricas de entrenamiento
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred, average='weighted')
    train_recall = recall_score(y_train, y_train_pred, average='weighted')
    train_f1 = f1_score(y_train, y_train_pred, average='weighted')

    # Calcular métricas de validación
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_precision = precision_score(y_val, y_val_pred, average='weighted')
    val_recall = recall_score(y_val, y_val_pred, average='weighted')
    val_f1 = f1_score(y_val, y_val_pred, average='weighted')

    # Almacenar las métricas en las listas
    train_accuracy_scores.append(train_accuracy)
    train_precision_scores.append(train_precision)
    train_recall_scores.append(train_recall)
    train_f1_scores.append(train_f1)

    val_accuracy_scores.append(val_accuracy)
    val_precision_scores.append(val_precision)
    val_recall_scores.append(val_recall)
    val_f1_scores.append(val_f1)

# Calcular las métricas promediadas en entrenamiento
train_accuracy_mean = np.mean(train_accuracy_scores)
train_precision_mean = np.mean(train_precision_scores)
train_recall_mean = np.mean(train_recall_scores)
train_f1_mean = np.mean(train_f1_scores)

# Calcular las métricas promediadas en validación
val_accuracy_mean = np.mean(val_accuracy_scores)
val_precision_mean = np.mean(val_precision_scores)
val_recall_mean = np.mean(val_recall_scores)
val_f1_mean = np.mean(val_f1_scores)

# Guardar el modelo entrenado
model.save('/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LDA/Experimentos pt2/modelo_entrenado_LDA(K=10).h5')

# Cargar el modelo entrenado
loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LDA/Experimentos pt2/modelo_entrenado_LDA(K=10).h5')
# Out:
# Epoch 1/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6096 - accuracy: 0.6565 - val_loss: 0.6040 - val_accuracy: 0.6642
# Epoch 2/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6056 - accuracy: 0.6592 - val_loss: 0.6008 - val_accuracy: 0.6671
# Epoch 3/1000
# 1107/1107 [==============================] - 9s 8ms/step - loss: 0.6039 - accuracy: 0.6591 - val_loss: 0.5996 - val_accuracy: 0.6644
# Epoch 4/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6027 - accuracy: 0.6601 - val_loss: 0.5966 - val_accuracy: 0.6686
# Epoch 5/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6015 - accuracy: 0.6604 - val_loss: 0.5962 - val_accuracy: 0.6664
# Epoch 6/1000
# 1107/1107 [==============================] - 9s 8ms/step - loss: 0.6008 - accuracy: 0.6603 - val_loss: 0.5962 - val_accuracy: 0.6680
# Epoch 7/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6004 - accuracy: 0.6603 - val_loss: 0.5945 - val_accuracy: 0.6682
# Epoch 8/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6001 - accuracy: 0.6612 - val_loss: 0.5963 - val_accuracy: 0.6662
# Epoch 9/1000
# 1107/1107 [==============================] - 9s 8ms/step - loss: 0.5996 - accuracy: 0.6610 - val_loss: 0.5955 - val_accuracy: 0.6660
# Epoch 10/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5994 - accuracy: 0.6610 - val_loss: 0.5941 - val_accuracy: 0.6665
# Epoch 11/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5989 - accuracy: 0.6621 - val_loss: 0.5946 - val_accuracy: 0.6680
# Epoch 12/1000
# 1107/1107 [==============================] - 9s 8ms/step - loss: 0.5988 - accuracy: 0.6612 - val_loss: 0.5937 - val_accuracy: 0.6664
# Epoch 13/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.
1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5927 - accuracy: 0.6631 - val_loss: 0.5940 - val_accuracy: 0.6636
# Epoch 38/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5925 - accuracy: 0.6634 - val_loss: 0.5934 - val_accuracy: 0.6588
# Epoch 39/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5926 - accuracy: 0.6632 - val_loss: 0.5941 - val_accuracy: 0.6590
# Epoch 40/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5926 - accuracy: 0.6633 - val_loss: 0.5944 - val_accuracy: 0.6633
# Epoch 41/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5927 - accuracy: 0.6625 - val_loss: 0.5950 - val_accuracy: 0.6605
# Epoch 42/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5925 - accuracy: 0.6627 - val_loss: 0.5939 - val_accuracy: 0.6612
# Epoch 43/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5922 - accuracy: 0.6634 - val_loss: 0.5942 - val_accuracy: 0.6591
# Epoch 44/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5923 - accuracy: 0.6636 - val_loss: 0.5939 - val_accuracy: 0.6614
# Epoch 45/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5920 - accuracy: 0.6640 - val_loss: 0.5941 - val_accuracy: 0.6601
# Epoch 46/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5920 - accuracy: 0.6638 - val_loss: 0.5943 - val_accuracy: 0.6607
# Epoch 47/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5920 - accuracy: 0.6636 - val_loss: 0.5940 - val_accuracy: 0.6623
# Epoch 48/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5919 - accuracy: 0.6637 - val_loss: 0.5941 - val_accuracy: 0.6606
# 6918/6918 [==============================] - 15s 2ms/step
# 769/769 [==============================] - 1s 2ms/step
# Epoch 1/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6108 - accuracy: 0.6633 - val_loss: 0.6007 - val_accuracy: 0.6727
# Epoch 2/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6046 - accuracy: 0.6661 - val_loss: 0.5986 - val_accuracy: 0.6740
# Epoch 3/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6023 - accuracy: 0.6673 - val_loss: 0.5967 - val_accuracy: 0.6744
# Epoch 4/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6002 - accuracy: 0.6686 - val_loss: 0.5947 - val_accuracy: 0.6737
# Epoch 5/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5991 - accuracy: 0.6690 - val_loss: 0.5965 - val_accuracy: 0.6757
# Epoch 6/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5986 - accuracy: 0.6696 - val_loss: 0.5971 - val_accuracy: 0.6753
# Epoch 7/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5982 - accuracy: 0.6692 - val_loss: 0.5945 - val_accuracy: 0.6754
# Epoch 8/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5978 - accuracy: 0.6700 - val_loss: 0.5928 - val_accuracy: 0.6766
# Epoch 9/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5974 - accuracy: 0.6695 - val_loss: 0.5926 - val_accuracy: 0.6768
# Epoch 10/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5973 - accuracy: 0.6700 - val_loss: 0.5928 - val_accuracy: 0.6755
# Epoch 11/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5969 - accuracy: 0.6700 - val_loss: 0.5945 - val_accuracy: 0.6758
# Epoch 12/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5966 - accuracy: 0.6703 - val_loss: 0.5924 - val_accuracy: 0.6763
# Epoch 13/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5964 - accuracy: 0.6707 - val_loss: 0.5926 - val_accuracy: 0.6760
# Epoch 14/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5963 - accuracy: 0.6706 - val_loss: 0.5925 - val_accuracy: 0.6767
# Epoch 15/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.5959 - accuracy: 0.6712 - val_loss: 0.5928 - val_accuracy: 0.6773
# Epoch 16/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5961 - accuracy: 0.6705 - val_loss: 0.5924 - val_accuracy: 0.6753
# Epoch 17/1000
# 1107/1107 [==============================] - 9s 9ms/step - loss: 0.5959 - accuracy: 0.6710 - val_loss: 0.5926 - val_accuracy: 0.6762
# Epoch 18/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5957 - accuracy: 0.6712 - val_loss: 0.5921 - val_accuracy: 0.6761
# Epoch 19/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5956 - accuracy: 0.6711 - val_loss: 0.5923 - val_accuracy: 0.6760
# Epoch 20/1000
# 1107/1107 [==============================] - 9s 8ms/step - loss: 0.5953 - accuracy: 0.6715 - val_loss: 0.5926 - val_accuracy: 0.6765
# Epoch 21/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5954 - accuracy: 0.6712 - val_loss: 0.5920 - val_accuracy: 0.6760
# Epoch 22/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5952 - accuracy: 0.6714 - val_loss: 0.5919 - val_accuracy: 0.6761
# Epoch 23/1000
# 1107/1107 [==============================] - 9s 8ms/step - loss: 0.5951 - accuracy: 0.6710 - val_loss: 0.5920 - val_accuracy: 0.6766
# Epoch 24/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5951 - accuracy: 0.6719 - val_loss: 0.5916 - val_accuracy: 0.6766
# Epoch 25/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.5949 - accuracy: 0.6715 - val_loss: 0.5925 - val_accuracy: 0.6770
# Epoch 26/1000
# ...
# Epoch 17/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6116 - accuracy: 0.6626 - val_loss: 0.6076 - val_accuracy: 0.6643
# Epoch 18/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6113 - accuracy: 0.6627 - val_loss: 0.6074 - val_accuracy: 0.6635
# Epoch 19/1000
# 1107/1107 [==============================] - 9s 9ms/step - loss: 0.6111 - accuracy: 0.6626 - val_loss: 0.6071 - val_accuracy: 0.6658
# Epoch 20/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6110 - accuracy: 0.6629 - val_loss: 0.6071 - val_accuracy: 0.6651
# Epoch 21/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6111 - accuracy: 0.6629 - val_loss: 0.6072 - val_accuracy: 0.6638
# Epoch 22/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6108 - accuracy: 0.6630 - val_loss: 0.6073 - val_accuracy: 0.6650
# Epoch 23/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6107 - accuracy: 0.6631 - val_loss: 0.6081 - val_accuracy: 0.6635
# 6918/6918 [==============================] - 14s 2ms/step
# 769/769 [==============================] - 1s 2ms/step
# Epoch 1/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6422 - accuracy: 0.6254 - val_loss: 0.6367 - val_accuracy: 0.6278
# Epoch 2/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6372 - accuracy: 0.6273 - val_loss: 0.6341 - val_accuracy: 0.6307
# Epoch 3/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6355 - accuracy: 0.6290 - val_loss: 0.6339 - val_accuracy: 0.6313
# Epoch 4/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6343 - accuracy: 0.6299 - val_loss: 0.6338 - val_accuracy: 0.6298
# Epoch 5/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6338 - accuracy: 0.6304 - val_loss: 0.6322 - val_accuracy: 0.6353
# Epoch 6/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6334 - accuracy: 0.6303 - val_loss: 0.6317 - val_accuracy: 0.6331
# Epoch 7/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6329 - accuracy: 0.6315 - val_loss: 0.6323 - val_accuracy: 0.6340
# Epoch 8/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6325 - accuracy: 0.6322 - val_loss: 0.6312 - val_accuracy: 0.6349
# Epoch 9/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6320 - accuracy: 0.6323 - val_loss: 0.6312 - val_accuracy: 0.6350
# Epoch 10/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6315 - accuracy: 0.6331 - val_loss: 0.6316 - val_accuracy: 0.6305
# Epoch 11/1000
# 1107/1107 [==============================] - 12s 11ms/step - loss: 0.6314 - accuracy: 0.6330 - val_loss: 0.6321 - val_accuracy: 0.6341
# Epoch 12/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6309 - accuracy: 0.6341 - val_loss: 0.6302 - val_accuracy: 0.6347
# Epoch 13/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6306 - accuracy: 0.6342 - val_loss: 0.6310 - val_accuracy: 0.6350
# Epoch 14/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6307 - accuracy: 0.6339 - val_loss: 0.6296 - val_accuracy: 0.6377
# Epoch 15/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6304 - accuracy: 0.6342 - val_loss: 0.6314 - val_accuracy: 0.6356
# Epoch 16/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.
1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6273 - accuracy: 0.6375 - val_loss: 0.6291 - val_accuracy: 0.6364
# Epoch 47/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6271 - accuracy: 0.6375 - val_loss: 0.6299 - val_accuracy: 0.6346
# Epoch 48/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6272 - accuracy: 0.6380 - val_loss: 0.6293 - val_accuracy: 0.6359
# Epoch 49/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6272 - accuracy: 0.6380 - val_loss: 0.6288 - val_accuracy: 0.6363
# Epoch 50/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6271 - accuracy: 0.6378 - val_loss: 0.6294 - val_accuracy: 0.6357
# 6918/6918 [==============================] - 14s 2ms/step
# 769/769 [==============================] - 1s 2ms/step
# Epoch 1/1000
# 1107/1107 [==============================] - 11s 9ms/step - loss: 0.6280 - accuracy: 0.6463 - val_loss: 0.6186 - val_accuracy: 0.6497
# Epoch 2/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6233 - accuracy: 0.6485 - val_loss: 0.6163 - val_accuracy: 0.6542
# Epoch 3/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6215 - accuracy: 0.6504 - val_loss: 0.6162 - val_accuracy: 0.6524
# Epoch 4/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6204 - accuracy: 0.6507 - val_loss: 0.6143 - val_accuracy: 0.6555
# Epoch 5/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6191 - accuracy: 0.6519 - val_loss: 0.6154 - val_accuracy: 0.6568
# Epoch 6/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6188 - accuracy: 0.6516 - val_loss: 0.6145 - val_accuracy: 0.6581
# Epoch 7/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6181 - accuracy: 0.6523 - val_loss: 0.6127 - val_accuracy: 0.6594
# Epoch 8/1000
# 1107/1107 [==============================] - 12s 11ms/step - loss: 0.6173 - accuracy: 0.6528 - val_loss: 0.6142 - val_accuracy: 0.6572
# Epoch 9/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6171 - accuracy: 0.6531 - val_loss: 0.6128 - val_accuracy: 0.6588
# Epoch 10/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6170 - accuracy: 0.6529 - val_loss: 0.6133 - val_accuracy: 0.6548
# Epoch 11/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6166 - accuracy: 0.6533 - val_loss: 0.6117 - val_accuracy: 0.6585
# Epoch 12/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6162 - accuracy: 0.6536 - val_loss: 0.6130 - val_accuracy: 0.6568
# Epoch 13/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6158 - accuracy: 0.6533 - val_loss: 0.6124 - val_accuracy: 0.6596
# Epoch 14/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6159 - accuracy: 0.6540 - val_loss: 0.6111 - val_accuracy: 0.6593
# Epoch 15/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6154 - accuracy: 0.6533 - val_loss: 0.6115 - val_accuracy: 0.6593
# Epoch 16/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6154 - accuracy: 0.6539 - val_loss: 0.6104 - val_accuracy: 0.6594
# Epoch 17/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6152 - accuracy: 0.6539 - val_loss: 0.6115 - val_accuracy: 0.6578
# Epoch 18/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6150 - accuracy: 0.6546 - val_loss: 0.6116 - val_accuracy: 0.6587
# Epoch 19/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6147 - accuracy: 0.6542 - val_loss: 0.6103 - val_accuracy: 0.6593
# Epoch 20/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6146 - accuracy: 0.6545 - val_loss: 0.6103 - val_accuracy: 0.6600
# Epoch 21/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6144 - accuracy: 0.6547 - val_loss: 0.6116 - val_accuracy: 0.6579
# Epoch 22/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6141 - accuracy: 0.6552 - val_loss: 0.6104 - val_accuracy: 0.6580
# Epoch 23/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6142 - accuracy: 0.6544 - val_loss: 0.6100 - val_accuracy: 0.6590
# Epoch 24/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6142 - accuracy: 0.6555 - val_loss: 0.6113 - val_accuracy: 0.6579
# Epoch 25/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6139 - accuracy: 0.6553 - val_loss: 0.6099 - val_accuracy: 0.6590
# Epoch 26/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6138 - accuracy: 0.6550 - val_loss: 0.6115 - val_accuracy: 0.6575
# Epoch 27/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6136 - accuracy: 0.6554 - val_loss: 0.6102 - val_accuracy: 0.6580
# Epoch 28/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6134 - accuracy: 0.6553 - val_loss: 0.6103 - val_accuracy: 0.6585
# Epoch 29/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6136 - accuracy: 0.6547 - val_loss: 0.6102 - val_accuracy: 0.6614
# Epoch 30/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6132 - accuracy: 0.6560 - val_loss: 0.6099 - val_accuracy: 0.6586
# Epoch 31/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6132 - accuracy: 0.6556 - val_loss: 0.6106 - val_accuracy: 0.6597
# Epoch 32/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6132 - accuracy: 0.6554 - val_loss: 0.6101 - val_accuracy: 0.6597
# Epoch 33/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6131 - accuracy: 0.6555 - val_loss: 0.6100 - val_accuracy: 0.6597
# Epoch 34/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6128 - accuracy: 0.6550 - val_loss: 0.6105 - val_accuracy: 0.6591
# Epoch 35/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6129 - accuracy: 0.6557 - val_loss: 0.6094 - val_accuracy: 0.6590
# Epoch 36/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6128 - accuracy: 0.6557 - val_loss: 0.6093 - val_accuracy: 0.6601
# Epoch 37/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6126 - accuracy: 0.6559 - val_loss: 0.6096 - val_accuracy: 0.6597
# Epoch 38/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6127 - accuracy: 0.6557 - val_loss: 0.6090 - val_accuracy: 0.6613
# Epoch 39/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6125 - accuracy: 0.6557 - val_loss: 0.6111 - val_accuracy: 0.6583
# Epoch 40/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6128 - accuracy: 0.6557 - val_loss: 0.6096 - val_accuracy: 0.6592
# Epoch 41/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6125 - accuracy: 0.6562 - val_loss: 0.6104 - val_accuracy: 0.6592
# Epoch 42/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6124 - accuracy: 0.6563 - val_loss: 0.6097 - val_accuracy: 0.6597
# Epoch 43/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6125 - accuracy: 0.6559 - val_loss: 0.6104 - val_accuracy: 0.6610
# Epoch 44/1000
# 1107/1107 [==============================] - 11s 10ms/step - loss: 0.6123 - accuracy: 0.6561 - val_loss: 0.6098 - val_accuracy: 0.6581
# Epoch 45/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6123 - accuracy: 0.6561 - val_loss: 0.6091 - val_accuracy: 0.6592
# Epoch 46/1000
# 1107/1107 [==============================] - 10s 9ms/step - loss: 0.6122 - accuracy: 0.6562 - val_loss: 0.6094 - val_accuracy: 0.6590
# Epoch 47/1000
# 1107/1107 [==============================] - 12s 10ms/step - loss: 0.6121 - accuracy: 0.6563 - val_loss: 0.6103 - val_accuracy: 0.6588
# Epoch 48/1000
# 1107/1107 [==============================] - 12s 11ms/step - loss: 0.6120 - accuracy: 0.6555 - val_loss: 0.6096 - val_accuracy: 0.6586
# 6918/6918 [==============================] - 15s 2ms/step
# 769/769 [==============================] - 1s 2ms/step

# %%
# Imprimir las métricas promediadas
print("Métricas de entrenamiento promediadas:")
print(f"Exactitud: {train_accuracy_mean * 100:.2f}%")
print(f"Precisión: {train_precision_mean * 100:.2f}%")
print(f"Recuperación: {train_recall_mean * 100:.2f}%")
print(f"Puntuación F1: {train_f1_mean * 100:.2f}%")

print("\nMétricas de validación promediadas:")
print(f"Exactitud: {val_accuracy_mean * 100:.2f}%")
print(f"Precisión: {val_precision_mean * 100:.2f}%")
print(f"Recuperación: {val_recall_mean * 100:.2f}%")
print(f"Puntuación F1: {val_f1_mean * 100:.2f}%")
# Out:
# Métricas de entrenamiento promediadas:
# Exactitud: 66.37%
# Precisión: 66.46%
# Recuperación: 66.37%
# Puntuación F1: 66.33%
#
# Métricas de validación promediadas:
# Exactitud: 66.47%
# Precisión: 66.55%
# Recuperación: 66.47%
# Puntuación F1: 66.44%

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_val_lda)

# Obtiene la matriz de confusión. Las filas corresponden a las clases reales,
umbral = 0.5  # Puedes ajustar este umbral según tus necesidades
y_pred_binario = (y_pred > umbral).astype(int)

# Calcular la matriz de confusión con las etiquetas binarias
cm = confusion_matrix(y_val, y_pred_binario)
prop_real = np.sum(y_val)/len(y_val)
prop_etiqutados = (cm[0,1]+cm[1,1])/len(y_val)

print("Matriz de confusión: \n\n", cm, "\n")
print('Proporción de comentarios positivos: %.2f'% prop_real)
print('Proporción de comentarios positivos etiquetados: %.2f'% prop_etiqutados)
# Out:
# 769/769 [==============================] - 2s 3ms/step
# Matriz de confusión:
#
#  [[8044 4450]
#  [3881 8220]]
#
# Proporción de comentarios positivos: 0.49
# Proporción de comentarios positivos etiquetados: 0.52

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una figura para la matriz de confusión
plt.figure(figsize=(8, 6))

# Crear una matriz de confusión usando el heatmap de Seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['0', '1'], yticklabels=['0', '1'])

# Etiquetas y título
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Guardar el modelo

# %%
import joblib
import os
# Directorio para guardar modelos entrenados
model_dir = '/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LDA/Experimentos pt2'
model_filename = 'TWEETS_depresivos (RN-LDA).pkl'
model_path_p = os.path.join(model_dir, model_filename)

# Guardar el modelo entrenado
joblib.dump(model, model_path_p)
# Out:
# ['/content/drive/MyDrive/Experimentación Python Tesis /Experimento Dataset Depresión/LDA/Experimentos pt2/TWEETS_depresivos (RN-LDA).pkl']

# %% [markdown]
# # Evaluación

# %%
# Aplicar las mismas transformaciones a los nuevos datos de prueba
data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(removeHTML)
data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(clean)
#data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(extractTerms)
data_test['TWEET_TEXT'] = data_test['TWEET_TEXT'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
# Aplicar LDA para reducir la dimensionalidad en los nuevos datos
X_test_new = count_vect.transform(data_test['TWEET_TEXT'].values)  # Aplicar el mismo vectorizador que se usó en los datos de entrenamiento
X_test_new_lda = lda.transform(X_test_new)
y_test_new = data_test['trastorno'].values
# Convertir las predicciones continuas en etiquetas binarias usando un umbral (por ejemplo, 0.5)
y_pred_new = model.predict(X_test_new_lda)
y_pred_new_binary = (y_pred_new > 0.5).astype(int)

# Calcular métricas de evaluación en los nuevos datos (si es necesario)
accuracy_new = accuracy_score(y_test_new, y_pred_new_binary)
precision_new = precision_score(y_test_new, y_pred_new_binary, average='weighted')
recall_new = recall_score(y_test_new, y_pred_new_binary, average='weighted')
f1_new = f1_score(y_test_new, y_pred_new_binary, average='weighted')

# Imprimir las métricas de evaluación en los nuevos datos
print("Métricas en los nuevos datos de prueba:")
print(f"Exactitud: {accuracy_new * 100:.2f}%")
print(f"Precisión: {precision_new * 100:.2f}%")
print(f"Recall: {recall_new * 100:.2f}%")
print(f"Puntuación F1: {f1_new * 100:.2f}%")
# Out:
# 3534/3534 [==============================] - 7s 2ms/step
# Métricas en los nuevos datos de prueba:
# Exactitud: 62.20%
# Precisión: 62.31%
# Recall: 62.20%
# Puntuación F1: 62.11%

# %% [markdown]
# # MATRIZ DE CONFUSIÓN

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test_lda)

# Obtiene la matriz de confusión. Las filas corresponden a las clases reales,
umbral = 0.5  # Puedes ajustar este umbral según tus necesidades
y_pred_binario = (y_pred > umbral).astype(int)

# Calcular la matriz de confusión con las etiquetas binarias
cm = confusion_matrix(y_test, y_pred_binario)
prop_real = np.sum(y_test)/len(y_test)
prop_etiqutados = (cm[0,1]+cm[1,1])/len(y_test)

print("Matriz de confusión: \n\n", cm, "\n")
print('Proporción de comentarios positivos: %.2f'% prop_real)
print('Proporción de comentarios positivos etiquetados: %.2f'% prop_etiqutados)
# Out:
# 2306/2306 [==============================] - 4s 2ms/step
# Matriz de confusión:
#
#  [[20748 16601]
#  [19835 16603]]
#
# Proporción de comentarios positivos: 0.49
# Proporción de comentarios positivos etiquetados: 0.45

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una figura para la matriz de confusión
plt.figure(figsize=(8, 6))

# Crear una matriz de confusión usando el heatmap de Seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['0', '1'], yticklabels=['0', '1'])

# Etiquetas y título
plt.xlabel('Predicción')
plt.ylabel('Valor Real')
plt.title('Matriz de Confusión')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Modelo Entrenado

# %%
# import joblib
# import numpy as np

# # Cargar el modelo entrenado
# model_path = '/content/drive/MyDrive/Experimentación Python Tesis /Modelos ya entrenados/TWEETS_depresivos (RL-Word2Vec).pkl'
# loaded_model = joblib.load(model_path)

# # Texto de ejemplo para predecir
# new_tweet = "RT @chicasuicida876: Mis cicatrices son prueba de que estoy luchando con demonios que están tratando de matarme😓💔"

# # Preprocesamiento del texto (asumiendo que ya tienes las funciones definidas)
# new_tweet_cleaned = clean(removeHTML(new_tweet))
# new_tweet_extracted = extractTerms(new_tweet_cleaned)

# # Supongamos que 'modelW' es tu modelo Word2Vec entrenado previamente
# new_tweet_word2vec = document_vector(new_tweet_extracted, modelW)

# # Redimensionar new_tweet_word2vec a una matriz 2D
# new_tweet_word2vec = np.array([new_tweet_word2vec])

# # Hacer la predicción y obtener las probabilidades de ambas clases
# proba_prediction = loaded_model.predict_proba(new_tweet_word2vec)
# control_prob = proba_prediction[0][0]  # Probabilidad de ser control
# depresion_prob = proba_prediction[0][1]  # Probabilidad de ser depresión
# # Imprimir el resultado de la predicción
# print(new_tweet)
# print('------------------------------------------------------------------')
# if depresion_prob > control_prob:
#     print("Este tweet es de depresión")
#     print("Probabilidad de que el tweet sea de depresión: {:.2f}%".format(depresion_prob * 100))
# else:
#     print("Este tweet No es de depresión")
#     print("Probabilidad de que el tweet no sea de depresión: {:.2f}%".format(control_prob * 100))
